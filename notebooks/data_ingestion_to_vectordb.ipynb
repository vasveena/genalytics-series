# %% [markdown]
# # Ingest massive amounts of data to a Vector DB (Amazon OpenSearch)
# **_Use of Amazon OpenSearch as a vector database for storing embeddings_**
#
# This notebook works well with the `conda_python3` kernel on a SageMaker Notebook `ml.t3.xlarge` instance.
#
# ---
# ---
#
# ## Contents
#
# 1. [Objective](#Objective)
# 1. [Background](#Background-(Problem-Description-and-Approach))
# 1. [Overall Workflow](#Overall-Workflow)
# 1. [Create scripts for ingesting data into OpenSearch](#Create-scripts-for-ingesting-data-into-OpenSearch)
# 1. [Download the data from the web and upload to S3](#Download-the-data-from-the-web-and-upload-to-S3)
# 1. [Load the data in a OpenSearch index (Local mode)](#Load-the-data-in-a-OpenSearch-index-(Local-mode))
# 1. [Load the data in a OpenSearch index via SageMaker Processing Job (Distributed mode)](#Load-the-data-in-a-OpenSearch-index-via-SageMaker-Processing-Job-(Distributed-mode))
# 1. [Conclusion](#Conclusion)

# %% [markdown]
# ---
#
# ## Objective
#
# This notebook illustrates how to use [`langchain`](https://python.langchain.com/en/latest/index.html) Amazon Sagemaker Endpoints and Amazon Sagemaker Processing Job to convert large amount of data into embeddings and ingest the text data along with its embeddings into an Amazon OpenSearch index.
#
# We use the documents from [sagemaker.readthedocs.io/en/stable](sagemaker.readthedocs.io/en/stable) as the dataset to convert into embeddings. The [`gpt-j-6b`](https://huggingface.co/EleutherAI/gpt-j-6b) large language model (LLM) is to generate the embeddings.
#
# To understand the code, you might also find it useful to refer to:
#
# - *[The langchain OpenSearch documentation](https://python.langchain.com/en/latest/ecosystem/opensearch.html)*
# - *[Amazon OpenSearch service documentation](https://docs.aws.amazon.com/opensearch-service/index.html)*
# - *[SageMaker Processing Job](https://docs.aws.amazon.com/sagemaker/latest/dg/processing-job.html)*
# ---
#
# ## Background (Problem Description and Approach)
#
# - **Problem statement**:
#
# Using LLMs for information retrieval tasks (such as question-answering) requires converting the knowledge corpus as well as user questions into vector embeddings. We want to generate these vector embeddings using an LLM hosted as a Amazon Sagemaker Endpoint and store it in a vector database of choice such as Amazon OpenSearch. For converting large amounts of data (TBs or PBs) we need a scalable system which can accomplish both converting the documents into embeddings, storing them in a vector database and provide low latency similarity search
#
# - **Our approach**:
#
# 1. Host the LLM use to generate the embeddings as a SageMaker Endpoint with `instance_count` set to > 1 (the exact number depends upon time taken to generate the embeddings for the amount of data we have and the dollar amount we want to spend on it; more instances would mean greater cost but also lesser time taken).
#
# 1. Place the data to be corpus of data in S3 (each document is a file stored as an object in S3).
#
# 1. Use a Python script that uses [langchain](https://python.langchain.com/en/latest/index.html) and [Opensearch-py](https://pypi.org/project/opensearch-py/) to ingest the data into OpenSearch. Run the script locally on this notebook for testing.
#
# 1. Create a Sagemaker Processing job with `instance_count` set to > 1 (usually matching the `instance_count` for the Sagemaker Endpoint).
#
#     Each instance of the SageMaker Processing Job runs a script that does the following:
#     - Processes a subset of files from S3.
#     - Uses langchain to read the files from the local filesystem and convert it into chunks.
#     - Creates a langchain `OpenSearchVectorSearch` object and provides it a `SagemakerJumpstartEmbeddings` object that enables it to talk to our Sagemaker Endpoint.
#     - Uses the langchain `OpenSearchVectorSearch` to create or get an existing Opensearch index and then ingests documents into the index which contain the original `text`, `embeddings` and `metadata`.
#     - Does this using Pytohn multiprocessing to achieve parallelization even within a single processing job instance and ensure maximum use of the Sagemaker Endpoint instance's GPU.
#     > **The advantage to using langchain as a wrapper for interfacing with a vector database is that it provides a generic pattern that can be used with any LLM and any vector store. Langchain automatically uses the OpenSearch bulk ingestion API endpoint for ingesting data rather than ingesting data one record at a time. Furthermore, langchain also provides an opinionated JSON structure that includes text and metadata alongwith the embeddings itself for storing embeddings in an OpenSearch index specifically for information retrieval use-cases**.
#
# - **Our tools**: [Amazon SageMaker SDK](https://sagemaker.readthedocs.io/en/stable/), [langchain](https://python.langchain.com/en/latest/index.html) and [Opensearch-py](https://pypi.org/project/opensearch-py/).

# %% [markdown]
# ---
#
# ## Overall Workflow
#
# **Prerequisite**
#
# The following are prerequisites that needs to be accomplised by running [this cloud formation template](./template.yaml) before running this notebook.
# - A Sagemaker Endpoint for generating embeddings.
# - An Amazon OpenSearch cluster for storing embeddings.
#     - Opensearch cluster's access credentials (username and password) stored in AWS Secrets Mananger by following steps described [here](https://docs.aws.amazon.com/secretsmanager/latest/userguide/managing-secrets.html).
#
# The overall workflow for this notebook is as follows:
# 1. Install the required Python packages and store session information in local variables.
# 1. Download data from source and upload to S3.
# 1. Run the Python script locally to ingest a subset of data into an OpenSearch index for testing.
# 1. Run Sagemaker Processing Job which reads all data from S3 and runs the same Python script as above to ingest data into OpenSearch.
#     - As part of this step we also create a custom container to package langchain and opensearch Python packages.
# 1. Do a similarity search with embeddings stored in the OpenSearch index for an input query.

# %% [markdown]
# ---
#
# ## Step 1: Setup
# Install the required packages.

# %%
# !pip install --upgrade sagemaker --quiet
# !pip install ipywidgets==7.0.0 langchain==0.0.149 opensearch-py==2.2.0 faiss_cpu==1.7.4 --quiet

# %%
import os
import sys
import time
import json
import logging
import numpy as np
from typing import List
import sagemaker, boto3, json
from sagemaker.session import Session
from sagemaker.processing import ProcessingInput
from langchain.document_loaders import ReadTheDocsLoader
from langchain.vectorstores import OpenSearchVectorSearch
from langchain.embeddings import SagemakerEndpointEmbeddings
from langchain.llms.sagemaker_endpoint import ContentHandlerBase
from langchain.text_splitter import RecursiveCharacterTextSplitter
from sagemaker.processing import ScriptProcessor, FrameworkProcessor
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %% [markdown]
# Change the parameters if you would like to scrape a different website for data, customize chunk size etc.

# %%
# global constants
WEBSITE="https://sagemaker.readthedocs.io/en/stable/"
DOMAIN="sagemaker.readthedocs.io"
DATA_DIR = "docs"
MAX_OS_DOCS_PER_PUT = 500
IMAGE = "load-data-opensearch-custom"
IMAGE_TAG = "latest"
CHUNK_SIZE_FOR_DOC_SPLIT = 600
CHUNK_OVERLAP_FOR_DOC_SPLIT = 20
CREATE_OS_INDEX_HINT_FILE = "_create_index_hint"
FAISS_INDEX_DIR = "faiss_index"

# %%
logger = logging.getLogger()
logging.basicConfig(format='%(asctime)s,%(module)s,%(processName)s,%(levelname)s,%(message)s', level=logging.INFO, stream=sys.stderr)

# %% [markdown]
# ### Read parameters from Cloud Formation stack
#
# Some of the resources needed for this notebook such as the Embeddings LLM model endpoint, the Amazon OpenSearch cluster are created outside of this notebook, typically through a cloud formation template. We now read the outputs and parameters of the cloud formation stack created from that template to get the value of these parameters.
#
# The stack name here should match the stack name you used when creating the cloud formation stack.

# %%
# if used a different name while creating the cloud formation stack then change this to match the name you used
CFN_STACK_NAME = "opensearch-vector-llm-rag"

# %% [markdown]
# **If you did not use a cloud formation template for creating these resources then set the names of these resources manually in the code below.**

# %%
#boto3.client('cloudformation').describe_stacks(StackName="ssome")
stacks = boto3.client('cloudformation').list_stacks()
stack_found = CFN_STACK_NAME in [stack['StackName'] for stack in stacks['StackSummaries']]
print(stack_found)
# Out:
# True

# %%
def get_cfn_outputs(stackname: str) -> List:
    cfn = boto3.client('cloudformation')
    outputs = {}
    for output in cfn.describe_stacks(StackName=stackname)['Stacks'][0]['Outputs']:
        outputs[output['OutputKey']] = output['OutputValue']
    return outputs

def get_cfn_parameters(stackname: str) -> List:
    cfn = boto3.client('cloudformation')
    params = {}
    for param in cfn.describe_stacks(StackName=stackname)['Stacks'][0]['Parameters']:
        params[param['ParameterKey']] = param['ParameterValue']
    return params

if stack_found is True:
    outputs = get_cfn_outputs(CFN_STACK_NAME)
    params = get_cfn_parameters(CFN_STACK_NAME)
    logger.info(f"cfn outputs={outputs}\nparams={params}")

    embeddings_model_endpoint_name = outputs['EmbeddingEndpointName']
    opensearch_domain_endpoint = f"https://{outputs['OpenSearchDomainEndpoint']}"
    opensearch_index = params['OpenSearchIndexName']
    app_name = params['AppName']
    # ARN of the secret is of the following format arn:aws:secretsmanager:region:account_id:secret:my_path/my_secret_name-autoid
    os_creds_secretid_in_secrets_manager = "-".join(outputs['OpenSearchSecret'].split(":")[-1].split('-')[:-1])
else:
    logger.info(f"cloud formation stack {CFN_STACK_NAME} not found, set parameters manually here")
    # REPLACE THE "placeholder" WITH ACTUAL VALUES IF YOU CREATED THESE RESOURCES WITHOUT USING A CLOUD FORMATION TEMPLATE
    embeddings_model_endpoint_name = "placeholder"
    opensearch_domain_endpoint = "placeholder"
    opensearch_index = "placeholder"
    os_creds_secretid_in_secrets_manager = "placeholder"
    app_name = "llm-apps"
# Out:
# 2024-01-11 07:43:19,958,1957501415,MainProcess,INFO,cfn outputs={'EmbeddingEndpointName': 'llm-apps-gpt-j-6b-endpoint-34b5c520', 'OpenSourceDomainArn': 'arn:aws:es:us-east-1:626103420214:domain/opensearchservi-yputae1aigke', 'OpenSearchDomainEndpoint': 'search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com', 'LLMEndpointName': 'llm-apps-flan-t5-xxl-endpoint-34b5c520', 'SageMakerNotebookURL': 'https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/notebook-instances/openNotebook/aws-llm-apps?view=classic', 'Region': 'us-east-1', 'OpenSearchDomainName': 'opensearchservi-yputae1aigke', 'LLMAppAPIEndpoint': 'https://05zu6d9o82.execute-api.us-east-1.amazonaws.com/prod/', 'OpenSearchSecret': 'arn:aws:secretsmanager:us-east-1:626103420214:secret:OpenSearchSecret-opensearch-vector-llm-rag-T5oYTQ'}
# params={'SageMakerIAMRole': 'LLMAppsIAMRole', 'SageMakerNotebookName': 'aws-llm-apps', 'OpenSearchIndexName': 'llm_apps_workshop_embeddings', 'LambdaFunctionName': 'LLMApp', 'OpenSearchUsername': 'opensearchuser', 'APIGatewayName': 'LLMAppAPIGW', 'ApiStageName': 'prod', 'OpenSearchPassword': '****', 'AppName': 'llm-apps'}

# %% [markdown]
# The embeddings model endpoint name, OpenSearch domain endpoint and the identifier for the OpenSearch credentials stored in the Secrets Mananger are all available as `Outputs` from the cloud formation stack.

# %%
logger.info(f"embeddings_model_endpoint_name={embeddings_model_endpoint_name},\nopensearch_domain_endpoint={opensearch_domain_endpoint},\n"
            f"os_creds_secretid_in_secrets_manager={os_creds_secretid_in_secrets_manager},opensearch_index={opensearch_index}")
# Out:
# 2024-01-11 07:43:22,721,796691109,MainProcess,INFO,embeddings_model_endpoint_name=llm-apps-gpt-j-6b-endpoint-34b5c520,
# opensearch_domain_endpoint=https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com,
# os_creds_secretid_in_secrets_manager=OpenSearchSecret-opensearch-vector-llm-rag,opensearch_index=llm_apps_workshop_embeddings

# %%
sagemaker_session = Session()
aws_role = sagemaker_session.get_caller_identity_arn()
aws_region = boto3.Session().region_name
bucket = sagemaker_session.default_bucket()
logger.info(f"aws_role={aws_role}, aws_region={aws_region}, bucket={bucket}")
# Out:
# 2024-01-11 07:43:33,307,1323976668,MainProcess,INFO,aws_role=arn:aws:iam::626103420214:role/LLMAppsIAMRole, aws_region=us-east-1, bucket=sagemaker-us-east-1-626103420214

# %% [markdown]
# ---
#
# ## Step 1: Download the data from the web and upload to S3
#
# In this step we use `wget` to crawl a Python documentation style website data. All files other than `html`, `txt` and `md` are removed. **This data download would take a few minutes**.

# %%
# !mkdir -p scripts

# %%
DOWNLOAD_DATA = "yes"

# %%
# %%writefile scripts/get_data.sh
# # This scripts uses wget to crawl the input website and
# # save the downloaded files in a given directory.
# echo "input args="
# echo $@
# if [[ "$1" == "yes" ]];
# then
#     WEBSITE=$2
#     DOMAIN=$3
#     KB_DIR=$4
#     # delete any existing folder for this data
#     rm -rf ${DOMAIN} ${KB_DIR}
#     mkdir -p ${KB_DIR}
#
#     # download the data, this may take a few minutes or more depending upon the amount of content, network speed etc.
#     wget -e robots=off --recursive --no-clobber --page-requisites --html-extension --convert-links --restrict-file-names=windows --domains ${DOMAIN} --no-parent ${WEBSITE}
#
#     # we only want to keep the html files
#     # and copy them into a new directory with their
#     # full path name flattened into a single file
#     # so /path/to/a/file becomes path_to_a_file, this
#     # is done so that we can upload all files to a single
#     # prefix in S3 which allows the Sagemaker Processing Job
#     # to easily split the files between instances
#     for i in `find ${DOMAIN} -name "*.html"`
#     do
#         flat_i=`echo "${i//\//_}"`
#         echo going to copy $i to ${KB_DIR}/$flat_i
#         cp $i ${KB_DIR}/$flat_i
#     done
#
#     file_count=`ls | wc -l`
#     echo there are $file_count files in ${DOMAIN} directory
# else
#     echo DOWNLOAD_DATA=$1, not downloading new data
# fi
# Out:
# Overwriting scripts/get_data.sh

# %%
# !chmod +x scripts/get_data.sh
# !./scripts/get_data.sh $DOWNLOAD_DATA $WEBSITE $DOMAIN $DATA_DIR
# Out:
# input args=
# yes https://sagemaker.readthedocs.io/en/stable/ sagemaker.readthedocs.io docs
# Both --no-clobber and --convert-links were specified, only --convert-links will be used.
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/
# Resolving sagemaker.readthedocs.io (sagemaker.readthedocs.io)... 104.17.32.82, 104.17.33.82, 2606:4700::6811:2152, ...
# Connecting to sagemaker.readthedocs.io (sagemaker.readthedocs.io)|104.17.32.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/index.html’
#
#     [ <=>                                   ] 53,855      --.-K/s   in 0.003s
#
# 2024-01-11 07:43:43 (15.8 MB/s) - ‘sagemaker.readthedocs.io/en/stable/index.html’ saved [53855]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/css/theme.css
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/theme.css’
#
#     [ <=>                                   ] 123,687     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:43 (208 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/theme.css’ saved [123687]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/pygments.css
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/pygments.css’
#
#     [ <=>                                   ] 4,902       --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (101 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/pygments.css’ saved [4902]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/theme_overrides.css
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 225 [text/css]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/theme_overrides.css’
#
# 100%[======================================>] 225         --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (57.5 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/theme_overrides.css’ saved [225/225]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/pagination.css
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/pagination.css’
#
#     [ <=>                                   ] 267         --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (30.6 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/pagination.css’ saved [267]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/search_accessories.css
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/search_accessories.css’
#
#     [ <=>                                   ] 586         --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (66.7 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/search_accessories.css’ saved [586]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/documentation_options.js
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 355 [text/javascript]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/documentation_options.js’
#
# 100%[======================================>] 355         --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (47.0 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/documentation_options.js’ saved [355/355]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/jquery.js
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 89476 (87K) [text/javascript]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/jquery.js’
#
# 100%[======================================>] 89,476      --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (393 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/jquery.js’ saved [89476/89476]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/underscore.js
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12140 (12K) [text/javascript]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/underscore.js’
#
# 100%[======================================>] 12,140      --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (310 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/underscore.js’ saved [12140/12140]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/doctools.js
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9354 (9.1K) [text/javascript]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/doctools.js’
#
# 100%[======================================>] 9,354       --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (239 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/doctools.js’ saved [9354/9354]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/language_data.js
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10847 (11K) [text/javascript]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/language_data.js’
#
# 100%[======================================>] 10,847      --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (237 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/language_data.js’ saved [10847/10847]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/js/datatable.js
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 121 [text/javascript]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/js/datatable.js’
#
# 100%[======================================>] 121         --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (17.9 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/js/datatable.js’ saved [121/121]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/_/static/javascript/readthedocs-doc-embed.js
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 32957 (32K) [text/javascript]
# Saving to: ‘sagemaker.readthedocs.io/_/static/javascript/readthedocs-doc-embed.js’
#
# 100%[======================================>] 32,957      --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (282 MB/s) - ‘sagemaker.readthedocs.io/_/static/javascript/readthedocs-doc-embed.js’ saved [32957/32957]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/_static/js/theme.js
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4916 (4.8K) [text/javascript]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/js/theme.js’
#
# 100%[======================================>] 4,916       --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (590 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/js/theme.js’ saved [4916/4916]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/genindex.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/genindex.html’
#
#     [ <=>                                   ] 393,125     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:43 (253 MB/s) - ‘sagemaker.readthedocs.io/en/stable/genindex.html’ saved [393125]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/search.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/search.html’
#
#     [ <=>                                   ] 37,353      --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (305 MB/s) - ‘sagemaker.readthedocs.io/en/stable/search.html’ saved [37353]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/overview.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/overview.html’
#
#     [ <=>                                   ] 385,493     --.-K/s   in 0.002s
#
# 2024-01-11 07:43:43 (224 MB/s) - ‘sagemaker.readthedocs.io/en/stable/overview.html’ saved [385493]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/_/static/css/readthedocs-doc-embed.css
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘sagemaker.readthedocs.io/_/static/css/readthedocs-doc-embed.css’
#
#     [ <=>                                   ] 6,300       --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (561 MB/s) - ‘sagemaker.readthedocs.io/_/static/css/readthedocs-doc-embed.css’ saved [6300]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/_/static/javascript/readthedocs-analytics.js
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2000 (2.0K) [text/javascript]
# Saving to: ‘sagemaker.readthedocs.io/_/static/javascript/readthedocs-analytics.js’
#
# 100%[======================================>] 2,000       --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (360 MB/s) - ‘sagemaker.readthedocs.io/_/static/javascript/readthedocs-analytics.js’ saved [2000/2000]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/v2.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/v2.html’
#
#     [ <=>                                   ] 96,142      --.-K/s   in 0s
#
# 2024-01-11 07:43:43 (365 MB/s) - ‘sagemaker.readthedocs.io/en/stable/v2.html’ saved [96142]
#
# --2024-01-11 07:43:43--  https://sagemaker.readthedocs.io/en/stable/api/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/index.html’
#
#     [ <=>                                   ] 45,515      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (315 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/index.html’ saved [45515]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/index.html’
#
#     [ <=>                                   ] 43,085      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (293 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/index.html’ saved [43085]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/algorithms/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/algorithms/index.html’
#
#     [ <=>                                   ] 44,762      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (314 MB/s) - ‘sagemaker.readthedocs.io/en/stable/algorithms/index.html’ saved [44762]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/workflows/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/workflows/index.html’
#
#     [ <=>                                   ] 39,577      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (290 MB/s) - ‘sagemaker.readthedocs.io/en/stable/workflows/index.html’ saved [39577]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/experiments/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/experiments/index.html’
#
#     [ <=>                                   ] 38,746      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (328 MB/s) - ‘sagemaker.readthedocs.io/en/stable/experiments/index.html’ saved [38746]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/amazon_sagemaker_debugger.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/amazon_sagemaker_debugger.html’
#
#     [ <=>                                   ] 92,038      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (311 MB/s) - ‘sagemaker.readthedocs.io/en/stable/amazon_sagemaker_debugger.html’ saved [92038]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/amazon_sagemaker_featurestore.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/amazon_sagemaker_featurestore.html’
#
#     [ <=>                                   ] 84,606      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (332 MB/s) - ‘sagemaker.readthedocs.io/en/stable/amazon_sagemaker_featurestore.html’ saved [84606]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/amazon_sagemaker_model_monitoring.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/amazon_sagemaker_model_monitoring.html’
#
#     [ <=>                                   ] 62,695      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (288 MB/s) - ‘sagemaker.readthedocs.io/en/stable/amazon_sagemaker_model_monitoring.html’ saved [62695]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/amazon_sagemaker_processing.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/amazon_sagemaker_processing.html’
#
#     [ <=>                                   ] 75,225      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (331 MB/s) - ‘sagemaker.readthedocs.io/en/stable/amazon_sagemaker_processing.html’ saved [75225]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/amazon_sagemaker_model_building_pipeline.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/amazon_sagemaker_model_building_pipeline.html’
#
#     [ <=>                                   ] 215,303     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:44 (241 MB/s) - ‘sagemaker.readthedocs.io/en/stable/amazon_sagemaker_model_building_pipeline.html’ saved [215303]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/api/prep_data/feature_store.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/prep_data/feature_store.html’
#
#     [ <=>                                   ] 250,405     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:44 (323 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/prep_data/feature_store.html’ saved [250405]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/api/training/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/training/index.html’
#
#     [ <=>                                   ] 41,425      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (233 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/training/index.html’ saved [41425]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/api/training/distributed.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/training/distributed.html’
#
#     [ <=>                                   ] 43,200      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (291 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/training/distributed.html’ saved [43200]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/api/inference/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/inference/index.html’
#
#     [ <=>                                   ] 41,760      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (348 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/inference/index.html’ saved [41760]
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/api/governance/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/governance/index.html’
#
#     [ <=>                                   ] 39,074      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (336 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/governance/index.html’ saved [39074]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/api/utility/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/utility/index.html’
#
#     [ <=>                                   ] 42,484      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (339 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/utility/index.html’ saved [42484]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/mxnet/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/mxnet/index.html’
#
#     [ <=>                                   ] 40,288      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (319 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/mxnet/index.html’ saved [40288]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/chainer/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/chainer/index.html’
#
#     [ <=>                                   ] 40,217      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (359 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/chainer/index.html’ saved [40217]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/huggingface/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/huggingface/index.html’
#
#     [ <=>                                   ] 41,501      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (363 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/huggingface/index.html’ saved [41501]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/pytorch/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/pytorch/index.html’
#
#     [ <=>                                   ] 39,645      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (297 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/pytorch/index.html’ saved [39645]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/rl/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/rl/index.html’
#
#     [ <=>                                   ] 40,135      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (353 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/rl/index.html’ saved [40135]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/sklearn/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/sklearn/index.html’
#
#     [ <=>                                   ] 40,429      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (214 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/sklearn/index.html’ saved [40429]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/sparkml/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/sparkml/index.html’
#
#     [ <=>                                   ] 39,769      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (331 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/sparkml/index.html’ saved [39769]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/tensorflow/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/tensorflow/index.html’
#
#     [ <=>                                   ] 41,179      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (380 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/tensorflow/index.html’ saved [41179]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/xgboost/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/xgboost/index.html’
#
#     [ <=>                                   ] 39,741      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (322 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/xgboost/index.html’ saved [39741]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/frameworks/djl/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/frameworks/djl/index.html’
#
#     [ <=>                                   ] 40,832      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (357 MB/s) - ‘sagemaker.readthedocs.io/en/stable/frameworks/djl/index.html’ saved [40832]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/algorithms/sagemaker.amazon.amazon_estimator.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/algorithms/sagemaker.amazon.amazon_estimator.html’
#
#     [ <=>                                   ] 59,238      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (301 MB/s) - ‘sagemaker.readthedocs.io/en/stable/algorithms/sagemaker.amazon.amazon_estimator.html’ saved [59238]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/algorithms/tabular/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/algorithms/tabular/index.html’
#
#     [ <=>                                   ] 40,586      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (359 MB/s) - ‘sagemaker.readthedocs.io/en/stable/algorithms/tabular/index.html’ saved [40586]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/algorithms/text/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/algorithms/text/index.html’
#
#     [ <=>                                   ] 42,222      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (316 MB/s) - ‘sagemaker.readthedocs.io/en/stable/algorithms/text/index.html’ saved [42222]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/algorithms/time_series/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/algorithms/time_series/index.html’
#
#     [ <=>                                   ] 39,322      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (378 MB/s) - ‘sagemaker.readthedocs.io/en/stable/algorithms/time_series/index.html’ saved [39322]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/algorithms/unsupervised/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/algorithms/unsupervised/index.html’
#
#     [ <=>                                   ] 39,755      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (349 MB/s) - ‘sagemaker.readthedocs.io/en/stable/algorithms/unsupervised/index.html’ saved [39755]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/algorithms/vision/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/algorithms/vision/index.html’
#
#     [ <=>                                   ] 42,209      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (345 MB/s) - ‘sagemaker.readthedocs.io/en/stable/algorithms/vision/index.html’ saved [42209]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/workflows/airflow/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/workflows/airflow/index.html’
#
#     [ <=>                                   ] 40,577      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (360 MB/s) - ‘sagemaker.readthedocs.io/en/stable/workflows/airflow/index.html’ saved [40577]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/workflows/step_functions/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/workflows/step_functions/index.html’
#
#     [ <=>                                   ] 39,799      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (352 MB/s) - ‘sagemaker.readthedocs.io/en/stable/workflows/step_functions/index.html’ saved [39799]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/workflows/pipelines/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/workflows/pipelines/index.html’
#
#     [ <=>                                   ] 41,434      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (188 MB/s) - ‘sagemaker.readthedocs.io/en/stable/workflows/pipelines/index.html’ saved [41434]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/workflows/lineage/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/workflows/lineage/index.html’
#
#     [ <=>                                   ] 40,071      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (344 MB/s) - ‘sagemaker.readthedocs.io/en/stable/workflows/lineage/index.html’ saved [40071]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/experiments/sagemaker.experiments.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/experiments/sagemaker.experiments.html’
#
#     [ <=>                                   ] 91,159      --.-K/s   in 0.003s
#
# 2024-01-11 07:43:44 (26.1 MB/s) - ‘sagemaker.readthedocs.io/en/stable/experiments/sagemaker.experiments.html’ saved [91159]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.eot?674f50d287a8c48dc19ba404d20fe713
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/vnd.ms-fontobject]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.eot@674f50d287a8c48dc19ba404d20fe713’
#
#     [ <=>                                   ] 165,742     --.-K/s   in 0.002s
#
# 2024-01-11 07:43:44 (98.3 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.eot@674f50d287a8c48dc19ba404d20fe713’ saved [165742]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.eot?674f50d287a8c48dc19ba404d20fe713?
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/vnd.ms-fontobject]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.eot@674f50d287a8c48dc19ba404d20fe713%3F’
#
#     [ <=>                                   ] 165,742     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:44 (111 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.eot@674f50d287a8c48dc19ba404d20fe713%3F’ saved [165742]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.woff2?af7ae505a9eed503f8b8e6982036873e
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 77160 (75K) [font/woff2]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.woff2@af7ae505a9eed503f8b8e6982036873e’
#
# 100%[======================================>] 77,160      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (366 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.woff2@af7ae505a9eed503f8b8e6982036873e’ saved [77160/77160]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.woff?fee66e712a8a08eef5805a46892932ad
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 98024 (96K) [font/woff]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.woff@fee66e712a8a08eef5805a46892932ad’
#
# 100%[======================================>] 98,024      --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (380 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.woff@fee66e712a8a08eef5805a46892932ad’ saved [98024/98024]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.ttf?b06871f281fee6b241d60582ae9369b9
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 165548 (162K) [font/ttf]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.ttf@b06871f281fee6b241d60582ae9369b9’
#
# 100%[======================================>] 165,548     --.-K/s   in 0s
#
# 2024-01-11 07:43:44 (381 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.ttf@b06871f281fee6b241d60582ae9369b9’ saved [165548/165548]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.svg?912ec66d7572ff821749319396470bde
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/svg+xml]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.svg@912ec66d7572ff821749319396470bde’
#
#     [ <=>                                   ] 444,379     --.-K/s   in 0.002s
#
# 2024-01-11 07:43:44 (196 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/fontawesome-webfont.svg@912ec66d7572ff821749319396470bde’ saved [444379]
#
# --2024-01-11 07:43:44--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal.woff2?bd03a2cc277bbbc338d464e679fe9942
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 182708 (178K) [font/woff2]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal.woff2@bd03a2cc277bbbc338d464e679fe9942’
#
# 100%[======================================>] 182,708     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:45 (283 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal.woff2@bd03a2cc277bbbc338d464e679fe9942’ saved [182708/182708]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal.woff?27bd77b9162d388cb8d4c4217c7c5e2a
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 309192 (302K) [font/woff]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal.woff@27bd77b9162d388cb8d4c4217c7c5e2a’
#
# 100%[======================================>] 309,192     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:45 (300 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal.woff@27bd77b9162d388cb8d4c4217c7c5e2a’ saved [309192/309192]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold.woff2?cccb897485813c7c256901dbca54ecf2
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 184912 (181K) [font/woff2]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold.woff2@cccb897485813c7c256901dbca54ecf2’
#
# 100%[======================================>] 184,912     --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (423 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold.woff2@cccb897485813c7c256901dbca54ecf2’ saved [184912/184912]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold.woff?d878b6c29b10beca227e9eef4246111b
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 309728 (302K) [font/woff]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold.woff@d878b6c29b10beca227e9eef4246111b’
#
# 100%[======================================>] 309,728     --.-K/s   in 0.002s
#
# 2024-01-11 07:43:45 (152 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold.woff@d878b6c29b10beca227e9eef4246111b’ saved [309728/309728]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold-italic.woff2?0b6bb6725576b072c5d0b02ecdd1900d
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 193308 (189K) [font/woff2]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold-italic.woff2@0b6bb6725576b072c5d0b02ecdd1900d’
#
# 100%[======================================>] 193,308     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:45 (257 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold-italic.woff2@0b6bb6725576b072c5d0b02ecdd1900d’ saved [193308/193308]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold-italic.woff?9c7e4e9eb485b4a121c760e61bc3707c
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 323344 (316K) [font/woff]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold-italic.woff@9c7e4e9eb485b4a121c760e61bc3707c’
#
# 100%[======================================>] 323,344     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:45 (271 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-bold-italic.woff@9c7e4e9eb485b4a121c760e61bc3707c’ saved [323344/323344]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal-italic.woff2?4eb103b4d12be57cb1d040ed5e162e9d
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 195704 (191K) [font/woff2]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal-italic.woff2@4eb103b4d12be57cb1d040ed5e162e9d’
#
# 100%[======================================>] 195,704     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:45 (282 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal-italic.woff2@4eb103b4d12be57cb1d040ed5e162e9d’ saved [195704/195704]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal-italic.woff?f28f2d6482446544ef1ea1ccc6dd5892
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 328412 (321K) [font/woff]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal-italic.woff@f28f2d6482446544ef1ea1ccc6dd5892’
#
# 100%[======================================>] 328,412     --.-K/s   in 0.002s
#
# 2024-01-11 07:43:45 (189 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/lato-normal-italic.woff@f28f2d6482446544ef1ea1ccc6dd5892’ saved [328412/328412]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Regular.woff2?7abf5b8d04d26a2cafea937019bca958
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 66444 (65K) [font/woff2]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Regular.woff2@7abf5b8d04d26a2cafea937019bca958’
#
# 100%[======================================>] 66,444      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (336 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Regular.woff2@7abf5b8d04d26a2cafea937019bca958’ saved [66444/66444]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Regular.woff?c1be9284088d487c5e3ff0a10a92e58c
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 86288 (84K) [font/woff]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Regular.woff@c1be9284088d487c5e3ff0a10a92e58c’
#
# 100%[======================================>] 86,288      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (247 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Regular.woff@c1be9284088d487c5e3ff0a10a92e58c’ saved [86288/86288]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Bold.woff2?9984f4a9bda09be08e83f2506954adbe
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 67312 (66K) [font/woff2]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Bold.woff2@9984f4a9bda09be08e83f2506954adbe’
#
# 100%[======================================>] 67,312      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (385 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Bold.woff2@9984f4a9bda09be08e83f2506954adbe’ saved [67312/67312]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Bold.woff?bed5564a116b05148e3b3bea6fb1162a
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 87624 (86K) [font/woff]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Bold.woff@bed5564a116b05148e3b3bea6fb1162a’
#
# 100%[======================================>] 87,624      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (432 MB/s) - ‘sagemaker.readthedocs.io/en/stable/_static/css/fonts/Roboto-Slab-Bold.woff@bed5564a116b05148e3b3bea6fb1162a’ saved [87624/87624]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/index.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/index.html’
#
#     [ <=>                                   ] 53,855      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (364 MB/s) - ‘sagemaker.readthedocs.io/en/stable/index.html’ saved [53855]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/workflows/pipelines/sagemaker.workflow.pipelines.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/workflows/pipelines/sagemaker.workflow.pipelines.html’
#
#     [ <=>                                   ] 334,286     --.-K/s   in 0.002s
#
# 2024-01-11 07:43:45 (162 MB/s) - ‘sagemaker.readthedocs.io/en/stable/workflows/pipelines/sagemaker.workflow.pipelines.html’ saved [334286]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/api/utility/instance_group.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/utility/instance_group.html’
#
#     [ <=>                                   ] 44,229      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (314 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/utility/instance_group.html’ saved [44229]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/api/utility/inputs.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/utility/inputs.html’
#
#     [ <=>                                   ] 93,576      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (314 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/utility/inputs.html’ saved [93576]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/api/inference/deserializers.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/inference/deserializers.html’
#
#     [ <=>                                   ] 84,685      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (287 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/inference/deserializers.html’ saved [84685]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/api/inference/predictors.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/inference/predictors.html’
#
#     [ <=>                                   ] 76,391      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (347 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/inference/predictors.html’ saved [76391]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/api/utility/session.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/utility/session.html’
#
#     [ <=>                                   ] 392,329     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:45 (300 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/utility/session.html’ saved [392329]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/algorithms/tabular/linear_learner.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/algorithms/tabular/linear_learner.html’
#
#     [ <=>                                   ] 159,839     --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (327 MB/s) - ‘sagemaker.readthedocs.io/en/stable/algorithms/tabular/linear_learner.html’ saved [159839]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/workflows/lineage/sagemaker.lineage.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/workflows/lineage/sagemaker.lineage.html’
#
#     [ <=>                                   ] 96,453      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (370 MB/s) - ‘sagemaker.readthedocs.io/en/stable/workflows/lineage/sagemaker.lineage.html’ saved [96453]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/api/inference/model.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/inference/model.html’
#
#     [ <=>                                   ] 265,284     --.-K/s   in 0.001s
#
# 2024-01-11 07:43:45 (312 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/inference/model.html’ saved [265284]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/api/inference/multi_data_model.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/inference/multi_data_model.html’
#
#     [ <=>                                   ] 58,649      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (354 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/inference/multi_data_model.html’ saved [58649]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/api/inference/model_collection.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/inference/model_collection.html’
#
#     [ <=>                                   ] 48,682      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (326 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/inference/model_collection.html’ saved [48682]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/api/governance/model_card.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sagemaker.readthedocs.io/en/stable/api/governance/model_card.html’
#
#     [ <=>                                   ] 82,665      --.-K/s   in 0s
#
# 2024-01-11 07:43:45 (259 MB/s) - ‘sagemaker.readthedocs.io/en/stable/api/governance/model_card.html’ saved [82665]
#
# --2024-01-11 07:43:45--  https://sagemaker.readthedocs.io/en/stable/api/training/algorithm.html
# Reusing existing connection to sagemaker.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# ...
# going to copy sagemaker.readthedocs.io/en/stable/api/training/sdp_versions/v1_1_x.html to docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1_1_x.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/sdp_versions/latest.html to docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_latest.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/sdp_versions/v1_2_x.html to docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1_2_x.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/sdp_versions/v1_0_0.html to docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1_0_0.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/sdp_versions/v1.2.x/smd_data_parallel_pytorch.html to docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.2.x_smd_data_parallel_pytorch.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/sdp_versions/v1.2.x/smd_data_parallel_tensorflow.html to docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.2.x_smd_data_parallel_tensorflow.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/sdp_versions/v1.0.0/smd_data_parallel_pytorch.html to docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.0.0_smd_data_parallel_pytorch.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/sdp_versions/v1.0.0/smd_data_parallel_tensorflow.html to docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.0.0_smd_data_parallel_tensorflow.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/sdp_versions/v1.1.x/smd_data_parallel_pytorch.html to docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.1.x_smd_data_parallel_pytorch.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/sdp_versions/v1.1.x/smd_data_parallel_tensorflow.html to docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.1.x_smd_data_parallel_tensorflow.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/debugger.html to docs/sagemaker.readthedocs.io_en_stable_api_training_debugger.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/smd_data_parallel_use_sm_pysdk.html to docs/sagemaker.readthedocs.io_en_stable_api_training_smd_data_parallel_use_sm_pysdk.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/algorithm.html to docs/sagemaker.readthedocs.io_en_stable_api_training_algorithm.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/distributed.html to docs/sagemaker.readthedocs.io_en_stable_api_training_distributed.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/analytics.html to docs/sagemaker.readthedocs.io_en_stable_api_training_analytics.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/processing.html to docs/sagemaker.readthedocs.io_en_stable_api_training_processing.html
# going to copy sagemaker.readthedocs.io/en/stable/api/training/estimators.html to docs/sagemaker.readthedocs.io_en_stable_api_training_estimators.html
# going to copy sagemaker.readthedocs.io/en/stable/api/prep_data/feature_store.html to docs/sagemaker.readthedocs.io_en_stable_api_prep_data_feature_store.html
# going to copy sagemaker.readthedocs.io/en/stable/genindex.html to docs/sagemaker.readthedocs.io_en_stable_genindex.html
# going to copy sagemaker.readthedocs.io/en/stable/transformer.html to docs/sagemaker.readthedocs.io_en_stable_transformer.html
# going to copy sagemaker.readthedocs.io/en/stable/sagemaker.mxnet.html to docs/sagemaker.readthedocs.io_en_stable_sagemaker.mxnet.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/time_series/index.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_time_series_index.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/time_series/deep_ar.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_time_series_deep_ar.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/index.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_index.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/image_classification_mxnet.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_classification_mxnet.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/object_detection_mxnet.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_mxnet.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/text_embedding_tensorflow_mxnet.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_text_embedding_tensorflow_mxnet.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/object_detection_pytorch.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_pytorch.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/object_detection_mxnet_gluoncv.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_mxnet_gluoncv.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/semantic_segmentation_mxnet.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_semantic_segmentation_mxnet.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/index.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_index.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/image_classification_tensorflow.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_classification_tensorflow.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/instance_segmentation_mxnet.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_instance_segmentation_mxnet.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/image_embedding_tensorflow.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_embedding_tensorflow.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/semantic_segmentation_mxnet_gluoncv.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_semantic_segmentation_mxnet_gluoncv.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/object_detection_tensorflow.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_tensorflow.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/vision/image_classification_pytorch.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_classification_pytorch.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/lda.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_lda.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/sequence_to_sequence.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_sequence_to_sequence.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/text_generation_hugging_face.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_text_generation_hugging_face.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/blazing_text.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_blazing_text.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/machine_translation_hugging_face.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_machine_translation_hugging_face.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/text_classification_tensorflow.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_text_classification_tensorflow.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/index.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_index.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/sentence_pair_classification_hugging_face.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_sentence_pair_classification_hugging_face.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/text_summarization_hugging_face.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_text_summarization_hugging_face.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/object2vec.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_object2vec.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/ntm.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_ntm.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/sentence_pair_classification_tensorflow.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_sentence_pair_classification_tensorflow.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/named_entity_recognition_hugging_face.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_named_entity_recognition_hugging_face.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/text/question_answering_pytorch.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_text_question_answering_pytorch.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/tabular/xgboost.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_xgboost.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/tabular/knn.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_knn.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/tabular/factorization_machines.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_factorization_machines.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/tabular/catboost.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_catboost.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/tabular/index.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_index.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/tabular/autogluon.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_autogluon.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/tabular/lightgbm.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_lightgbm.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/tabular/linear_learner.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_linear_learner.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/tabular/tabtransformer.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_tabtransformer.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/unsupervised/ipinsights.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_ipinsights.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/unsupervised/pca.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_pca.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/unsupervised/kmeans.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_kmeans.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/unsupervised/index.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_index.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/unsupervised/randomcutforest.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_randomcutforest.html
# going to copy sagemaker.readthedocs.io/en/stable/algorithms/sagemaker.amazon.amazon_estimator.html to docs/sagemaker.readthedocs.io_en_stable_algorithms_sagemaker.amazon.amazon_estimator.html
# going to copy sagemaker.readthedocs.io/en/stable/index.html to docs/sagemaker.readthedocs.io_en_stable_index.html
# going to copy sagemaker.readthedocs.io/en/stable/v2.html to docs/sagemaker.readthedocs.io_en_stable_v2.html
# going to copy sagemaker.readthedocs.io/en/stable/debugger.html to docs/sagemaker.readthedocs.io_en_stable_debugger.html
# going to copy sagemaker.readthedocs.io/en/stable/amazon_sagemaker_model_building_pipeline.html to docs/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_model_building_pipeline.html
# going to copy sagemaker.readthedocs.io/en/stable/using_mxnet.html to docs/sagemaker.readthedocs.io_en_stable_using_mxnet.html
# going to copy sagemaker.readthedocs.io/en/stable/amazon_sagemaker_model_monitoring.html to docs/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_model_monitoring.html
# going to copy sagemaker.readthedocs.io/en/stable/workflows/step_functions/index.html to docs/sagemaker.readthedocs.io_en_stable_workflows_step_functions_index.html
# going to copy sagemaker.readthedocs.io/en/stable/workflows/index.html to docs/sagemaker.readthedocs.io_en_stable_workflows_index.html
# going to copy sagemaker.readthedocs.io/en/stable/workflows/lineage/sagemaker.lineage.html to docs/sagemaker.readthedocs.io_en_stable_workflows_lineage_sagemaker.lineage.html
# going to copy sagemaker.readthedocs.io/en/stable/workflows/lineage/index.html to docs/sagemaker.readthedocs.io_en_stable_workflows_lineage_index.html
# going to copy sagemaker.readthedocs.io/en/stable/workflows/pipelines/sagemaker.workflow.pipelines.html to docs/sagemaker.readthedocs.io_en_stable_workflows_pipelines_sagemaker.workflow.pipelines.html
# going to copy sagemaker.readthedocs.io/en/stable/workflows/pipelines/index.html to docs/sagemaker.readthedocs.io_en_stable_workflows_pipelines_index.html
# going to copy sagemaker.readthedocs.io/en/stable/workflows/airflow/using_workflow.html to docs/sagemaker.readthedocs.io_en_stable_workflows_airflow_using_workflow.html
# going to copy sagemaker.readthedocs.io/en/stable/workflows/airflow/index.html to docs/sagemaker.readthedocs.io_en_stable_workflows_airflow_index.html
# going to copy sagemaker.readthedocs.io/en/stable/workflows/airflow/sagemaker.workflow.airflow.html to docs/sagemaker.readthedocs.io_en_stable_workflows_airflow_sagemaker.workflow.airflow.html
# going to copy sagemaker.readthedocs.io/en/stable/s3.html to docs/sagemaker.readthedocs.io_en_stable_s3.html
# going to copy sagemaker.readthedocs.io/en/stable/amazon_sagemaker_featurestore.html to docs/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_featurestore.html
# going to copy sagemaker.readthedocs.io/en/stable/analytics.html to docs/sagemaker.readthedocs.io_en_stable_analytics.html
# going to copy sagemaker.readthedocs.io/en/stable/search.html to docs/sagemaker.readthedocs.io_en_stable_search.html
# going to copy sagemaker.readthedocs.io/en/stable/amazon_sagemaker_debugger.html to docs/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_debugger.html
# going to copy sagemaker.readthedocs.io/en/stable/processing.html to docs/sagemaker.readthedocs.io_en_stable_processing.html
# going to copy sagemaker.readthedocs.io/en/stable/estimators.html to docs/sagemaker.readthedocs.io_en_stable_estimators.html
# going to copy sagemaker.readthedocs.io/en/stable/predictors.html to docs/sagemaker.readthedocs.io_en_stable_predictors.html
# going to copy sagemaker.readthedocs.io/en/stable/model_monitor.html to docs/sagemaker.readthedocs.io_en_stable_model_monitor.html
# going to copy sagemaker.readthedocs.io/en/stable/remote_function/sagemaker.remote_function.html to docs/sagemaker.readthedocs.io_en_stable_remote_function_sagemaker.remote_function.html
# going to copy sagemaker.readthedocs.io/en/stable/doc_utils/pretrainedmodels.html to docs/sagemaker.readthedocs.io_en_stable_doc_utils_pretrainedmodels.html
# going to copy sagemaker.readthedocs.io/en/stable/overview.html to docs/sagemaker.readthedocs.io_en_stable_overview.html
# going to copy sagemaker.readthedocs.io/en/stable/amazon_sagemaker_processing.html to docs/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_processing.html
# going to copy sagemaker.readthedocs.io/en/stable/sagemaker.tensorflow.html to docs/sagemaker.readthedocs.io_en_stable_sagemaker.tensorflow.html
# there are 14 files in sagemaker.readthedocs.io directory

# %%
# create a dummy file called _create_index to provide a hint for opensearch index creation
# this is needed for Sagemaker Processing Job when there are multiple instance nodes
# all running the same code for data ingestion but only one node needs to create the index
# !touch $DATA_DIR/$CREATE_OS_INDEX_HINT_FILE

# upload this data to S3, to be used when we run the Sagemaker Processing Job
# !aws s3 cp --recursive $DATA_DIR/ s3://$bucket/$app_name/$DOMAIN
# Out:
# upload: docs/_create_index_hint to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/_create_index_hint
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_sagemaker.amazon.amazon_estimator.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_sagemaker.amazon.amazon_estimator.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_lightgbm.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_tabular_lightgbm.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_tabular_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_tabtransformer.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_tabular_tabtransformer.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_autogluon.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_tabular_autogluon.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_catboost.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_tabular_catboost.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_machine_translation_hugging_face.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_machine_translation_hugging_face.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_object2vec.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_object2vec.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_xgboost.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_tabular_xgboost.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_blazing_text.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_blazing_text.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_named_entity_recognition_hugging_face.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_named_entity_recognition_hugging_face.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_text_generation_hugging_face.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_text_generation_hugging_face.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_knn.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_tabular_knn.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_ntm.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_ntm.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_sentence_pair_classification_tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_sentence_pair_classification_tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_factorization_machines.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_tabular_factorization_machines.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_text_summarization_hugging_face.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_text_summarization_hugging_face.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_sentence_pair_classification_hugging_face.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_sentence_pair_classification_hugging_face.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_time_series_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_time_series_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_text_classification_tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_text_classification_tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_tabular_linear_learner.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_tabular_linear_learner.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_lda.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_lda.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_time_series_deep_ar.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_time_series_deep_ar.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_sequence_to_sequence.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_sequence_to_sequence.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_text_question_answering_pytorch.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_text_question_answering_pytorch.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_ipinsights.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_ipinsights.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_pca.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_pca.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_embedding_tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_embedding_tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_classification_mxnet.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_classification_mxnet.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_kmeans.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_kmeans.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_instance_segmentation_mxnet.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_instance_segmentation_mxnet.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_randomcutforest.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_unsupervised_randomcutforest.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_classification_pytorch.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_classification_pytorch.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_mxnet.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_mxnet.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_pytorch.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_pytorch.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_mxnet_gluoncv.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_mxnet_gluoncv.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_semantic_segmentation_mxnet_gluoncv.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_semantic_segmentation_mxnet_gluoncv.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_object_detection_tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_classification_tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_image_classification_tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_semantic_segmentation_mxnet.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_semantic_segmentation_mxnet.html
# upload: docs/sagemaker.readthedocs.io_en_stable_algorithms_vision_text_embedding_tensorflow_mxnet.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_algorithms_vision_text_embedding_tensorflow_mxnet.html
# upload: docs/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_model_monitoring.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_model_monitoring.html
# upload: docs/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_debugger.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_debugger.html
# upload: docs/sagemaker.readthedocs.io_en_stable_analytics.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_analytics.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_governance_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_governance_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_featurestore.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_featurestore.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_governance_model_card.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_governance_model_card.html
# upload: docs/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_processing.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_processing.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_async_inference.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_async_inference.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_deserializers.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_deserializers.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_model_builder.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_model_builder.html
# upload: docs/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_model_building_pipeline.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_amazon_sagemaker_model_building_pipeline.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_explainer.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_explainer.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_multi_data_model.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_multi_data_model.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_pipeline.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_pipeline.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_model_collection.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_model_collection.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_predictor_async.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_predictor_async.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_serializers.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_serializers.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_predictors.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_predictors.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_analytics.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_analytics.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_transformer.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_transformer.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_model_monitor.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_model_monitor.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_debugger.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_debugger.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_model.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_model.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_algorithm.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_algorithm.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_estimators.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_estimators.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_inference_serverless.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_inference_serverless.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_prep_data_feature_store.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_prep_data_feature_store.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_profiler.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_profiler.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_distributed.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_distributed.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_automl.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_automl.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_latest_smd_data_parallel_tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_latest_smd_data_parallel_tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.0.0_smd_data_parallel_pytorch.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.0.0_smd_data_parallel_pytorch.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_latest_smd_data_parallel_pytorch.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_latest_smd_data_parallel_pytorch.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_latest.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_latest.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_parameter.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_parameter.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.1.x_smd_data_parallel_pytorch.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.1.x_smd_data_parallel_pytorch.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_processing.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_processing.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.2.x_smd_data_parallel_pytorch.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.2.x_smd_data_parallel_pytorch.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.0.0_smd_data_parallel_tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.0.0_smd_data_parallel_tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.1.x_smd_data_parallel_tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.1.x_smd_data_parallel_tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_archives.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_archives.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.2.x_smd_data_parallel_tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1.2.x_smd_data_parallel_tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1_1_x.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1_1_x.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_smd_data_parallel_release_notes_smd_data_parallel_change_log.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_smd_data_parallel_release_notes_smd_data_parallel_change_log.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_tuner.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_tuner.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1_0_0.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1_0_0.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1_2_x.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_sdp_versions_v1_2_x.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_accept_types.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_accept_types.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_smd_data_parallel.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_smd_data_parallel.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_content_types.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_content_types.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_config.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_config.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_featuregroup_utils.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_featuregroup_utils.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_training_smd_data_parallel_use_sm_pysdk.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_training_smd_data_parallel_use_sm_pysdk.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_environment_variables.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_environment_variables.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_hyperparameters.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_hyperparameters.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_image_uris.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_image_uris.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_inputs.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_inputs.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_instance_types.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_instance_types.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_lambda_helper.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_lambda_helper.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_instance_group.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_instance_group.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_model_uris.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_model_uris.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_metric_definitions.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_metric_definitions.html
# upload: docs/sagemaker.readthedocs.io_en_stable_debugger.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_debugger.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_script_uris.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_script_uris.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_s3.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_s3.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_network.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_network.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_interactive_apps.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_interactive_apps.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_chainer_sagemaker.chainer.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_chainer_sagemaker.chainer.html
# upload: docs/sagemaker.readthedocs.io_en_stable_api_utility_session.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_api_utility_session.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_chainer_using_chainer.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_chainer_using_chainer.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_chainer_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_chainer_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_experiments_sagemaker.experiments.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_experiments_sagemaker.experiments.html
# upload: docs/sagemaker.readthedocs.io_en_stable_experiments_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_experiments_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_djl_using_djl.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_djl_using_djl.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_djl_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_djl_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_doc_utils_pretrainedmodels.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_doc_utils_pretrainedmodels.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_djl_sagemaker.djl_inference.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_djl_sagemaker.djl_inference.html
# upload: docs/sagemaker.readthedocs.io_en_stable_estimators.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_estimators.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_huggingface_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_huggingface_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_mxnet_sagemaker.mxnet.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_mxnet_sagemaker.mxnet.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_rl_sagemaker.rl.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_rl_sagemaker.rl.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_pytorch_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_pytorch_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_mxnet_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_mxnet_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_pytorch_sagemaker.pytorch.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_pytorch_sagemaker.pytorch.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_rl_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_rl_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_huggingface_sagemaker.huggingface.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_huggingface_sagemaker.huggingface.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_sklearn_using_sklearn.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_sklearn_using_sklearn.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_sklearn_sagemaker.sklearn.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_sklearn_sagemaker.sklearn.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_mxnet_using_mxnet.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_mxnet_using_mxnet.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_rl_using_rl.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_rl_using_rl.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_sklearn_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_sklearn_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_sparkml_sagemaker.sparkml.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_sparkml_sagemaker.sparkml.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_pytorch_using_pytorch.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_pytorch_using_pytorch.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_tensorflow_sagemaker.tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_tensorflow_sagemaker.tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_sparkml_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_sparkml_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_tensorflow_deploying_tensorflow_serving.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_tensorflow_deploying_tensorflow_serving.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_xgboost_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_xgboost_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_xgboost_using_xgboost.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_xgboost_using_xgboost.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_tensorflow_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_tensorflow_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_predictors.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_predictors.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_xgboost_xgboost.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_xgboost_xgboost.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_tensorflow_upgrade_from_legacy.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_tensorflow_upgrade_from_legacy.html
# upload: docs/sagemaker.readthedocs.io_en_stable_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_remote_function_sagemaker.remote_function.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_remote_function_sagemaker.remote_function.html
# upload: docs/sagemaker.readthedocs.io_en_stable_model_monitor.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_model_monitor.html
# upload: docs/sagemaker.readthedocs.io_en_stable_frameworks_tensorflow_using_tf.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_frameworks_tensorflow_using_tf.html
# upload: docs/sagemaker.readthedocs.io_en_stable_processing.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_processing.html
# upload: docs/sagemaker.readthedocs.io_en_stable_overview.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_overview.html
# upload: docs/sagemaker.readthedocs.io_en_stable_genindex.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_genindex.html
# upload: docs/sagemaker.readthedocs.io_en_stable_search.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_search.html
# upload: docs/sagemaker.readthedocs.io_en_stable_transformer.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_transformer.html
# upload: docs/sagemaker.readthedocs.io_en_stable_sagemaker.tensorflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_sagemaker.tensorflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_v2.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_v2.html
# upload: docs/sagemaker.readthedocs.io_en_stable_workflows_airflow_sagemaker.workflow.airflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_workflows_airflow_sagemaker.workflow.airflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_using_mxnet.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_using_mxnet.html
# upload: docs/sagemaker.readthedocs.io_en_stable_workflows_lineage_sagemaker.lineage.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_workflows_lineage_sagemaker.lineage.html
# upload: docs/sagemaker.readthedocs.io_en_stable_workflows_airflow_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_workflows_airflow_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_workflows_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_workflows_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_sagemaker.mxnet.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_sagemaker.mxnet.html
# upload: docs/sagemaker.readthedocs.io_en_stable_workflows_airflow_using_workflow.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_workflows_airflow_using_workflow.html
# upload: docs/sagemaker.readthedocs.io_en_stable_workflows_lineage_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_workflows_lineage_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_workflows_step_functions_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_workflows_step_functions_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_tuner.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_tuner.html
# upload: docs/sagemaker.readthedocs.io_en_stable_workflows_pipelines_sagemaker.workflow.pipelines.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_workflows_pipelines_sagemaker.workflow.pipelines.html
# upload: docs/sagemaker.readthedocs.io_en_stable_workflows_pipelines_index.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_workflows_pipelines_index.html
# upload: docs/sagemaker.readthedocs.io_en_stable_s3.html to s3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io/sagemaker.readthedocs.io_en_stable_s3.html

# %% [markdown]
# ---
#
# ## Step 2: Load data into `OpenSearch`
#
# We are now ready to create scripts which will read data from the local directory, use langchain to create embeddings and then upload the embeddings into OpenSearch.

# %%
"""
Create directories for storing scripts and Dockerfile
"""
# !mkdir -p src
# !mkdir -p scripts
# !mkdir -p container

# %% [markdown]
# ### Read credentials from AWS Secrets Manager
#
# The credentials for the OpenSearch cluster are store in AWS Secrets Mananger, our code reads the credentials from there and provides them to the opensearch-py package (through langchain API).

# %%
# %%writefile container/credentials.py

"""
Retrieve credentials password for given username from AWS SecretsManager
"""
import json
import boto3

def get_credentials(secret_id: str, region_name: str) -> str:
    
    client = boto3.client('secretsmanager', region_name=region_name)
    response = client.get_secret_value(SecretId=secret_id)
    secrets_value = json.loads(response['SecretString'])    
    
    return secrets_value
# Out:
# Overwriting container/credentials.py

# %% [markdown]
# ### SageMaker embeddings for langchain
#
# langchain provides the [`SagemakerEndpointEmbeddings`]() class which is a wrapper around a functionality to talk to a Sagemaker Endpoint to generate embeddings. We will override the `embed_documents` function to define our own batching strategy for sending requests to the model (multiple requests are sent in one model invocation). Similarly, we extend the `ContentHandlerBase` class to provide implementation for two abstract methods which define how to process (encode/decode) the input data sent to the model and the output received from the model.
#
# We finally create a `SagemakerEndpointEmbeddingsJumpStart` object that puts all this together and can now be used by langchain to talk to an LLM deployed as a Sagemaker Endpoint to generate embeddings.

# %%
# %%writefile container/sm_helper.py

"""
Helper functions for using Samgemaker Endpoint via langchain
"""
import time
import json
import logging
from typing import List
from langchain.embeddings import SagemakerEndpointEmbeddings
from langchain.embeddings.sagemaker_endpoint import EmbeddingsContentHandler

logger = logging.getLogger(__name__)

# extend the SagemakerEndpointEmbeddings class from langchain to provide a custom embedding function
class SagemakerEndpointEmbeddingsJumpStart(SagemakerEndpointEmbeddings):
    def embed_documents(
        self, texts: List[str], chunk_size: int = 5
    ) -> List[List[float]]:
        """Compute doc embeddings using a SageMaker Inference Endpoint.

        Args:
            texts: The list of texts to embed.
            chunk_size: The chunk size defines how many input texts will
                be grouped together as request. If None, will use the
                chunk size specified by the class.

        Returns:
            List of embeddings, one for each text.
        """
        results = []
        _chunk_size = len(texts) if chunk_size > len(texts) else chunk_size
        st = time.time()
        for i in range(0, len(texts), _chunk_size):
            response = self._embedding_func(texts[i:i + _chunk_size])
            results.extend(response)
        time_taken = time.time() - st
        logger.info(f"got results for {len(texts)} in {time_taken}s, length of embeddings list is {len(results)}")
        return results


# class for serializing/deserializing requests/responses to/from the embeddings model
class ContentHandler(EmbeddingsContentHandler):
    content_type = "application/json"
    accepts = "application/json"

    def transform_input(self, prompt: str, model_kwargs={}) -> bytes:

        input_str = json.dumps({"text_inputs": prompt, **model_kwargs})
        return input_str.encode('utf-8') 

    def transform_output(self, output: bytes) -> str:

        response_json = json.loads(output.read().decode("utf-8"))
        embeddings = response_json["embedding"]
        if len(embeddings) == 1:
            return [embeddings[0]]
        return embeddings
    

def create_sagemaker_embeddings_from_js_model(embeddings_model_endpoint_name: str, aws_region: str) -> SagemakerEndpointEmbeddingsJumpStart:
    # all set to create the objects for the ContentHandler and 
    # SagemakerEndpointEmbeddingsJumpStart classes
    content_handler = ContentHandler()

    # note the name of the LLM Sagemaker endpoint, this is the model that we would
    # be using for generating the embeddings
    embeddings = SagemakerEndpointEmbeddingsJumpStart( 
        endpoint_name=embeddings_model_endpoint_name,
        region_name=aws_region, 
        content_handler=content_handler
    )
    return embeddings
# Out:
# Overwriting container/sm_helper.py

# %% [markdown]
# ### Script to load data into OpenSearch
#
# This script puts everything together, it divides the documents into chunks, then uses the langchain package to create embeddings (through `SagemakerEndpointEmbeddingsJumpStart`) and then ingests the data into OpenSearch using `OpenSearchVectorSearch`.
#
# To keep things simple the chunks size is set to a fixed length of 500 tokens, with an overlap of 30 tokens. The langchain `OpenSearchVectorSearch` provides a wrapper over the `opensearch-py` package. It uses the `/_bulk` API endpoint for ingesting multiple records in a single PUT request.

# %%
# %%writefile container/load_data_into_opensearch.py

import os
import sys

# this is needed because the credentials.py and sm_helper.py
# are in /code directory of the custom container we are going 
# to create for Sagemaker Processing Job
sys.path.insert(1, '/code')

import glob
import time
import json
import logging
import argparse
import numpy as np
import multiprocessing as mp
from itertools import repeat
from functools import partial
import sagemaker, boto3, json
from typing import List, Tuple
from sagemaker.session import Session
from credentials import get_credentials
from opensearchpy.client import OpenSearch
from langchain.document_loaders import ReadTheDocsLoader
from langchain.vectorstores import OpenSearchVectorSearch
from langchain.embeddings import SagemakerEndpointEmbeddings
from sm_helper import create_sagemaker_embeddings_from_js_model
from langchain.llms.sagemaker_endpoint import ContentHandlerBase
from langchain.text_splitter import RecursiveCharacterTextSplitter
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth

# global constants
MAX_OS_DOCS_PER_PUT = 500
TOTAL_INDEX_CREATION_WAIT_TIME = 60
PER_ITER_SLEEP_TIME = 5
logger = logging.getLogger()
logging.basicConfig(format='%(asctime)s,%(module)s,%(processName)s,%(levelname)s,%(message)s', level=logging.INFO, stream=sys.stderr)

def check_if_index_exists(index_name: str, region: str, host: str, http_auth: Tuple[str, str]) -> OpenSearch:
    #update the region if you're working other than us-east-1

    aos_client = OpenSearch(
        hosts = [{'host': host.replace("https://", ""), 'port': 443}],
        http_auth = http_auth,
        use_ssl = True,
        verify_certs = True,
        connection_class = RequestsHttpConnection
    )
    exists = aos_client.indices.exists(index_name)
    logger.info(f"index_name={index_name}, exists={exists}")
    return exists

    
def process_shard(shard, embeddings_model_endpoint_name, aws_region, os_index_name, os_domain_ep, os_http_auth) -> int: 
    logger.info(f'Starting process_shard of {len(shard)} chunks.')
    st = time.time()
    embeddings = create_sagemaker_embeddings_from_js_model(embeddings_model_endpoint_name, aws_region)
    docsearch = OpenSearchVectorSearch(index_name=os_index_name,
                                       embedding_function=embeddings,
                                       opensearch_url=os_domain_ep,
                                       http_auth=os_http_auth)    
    docsearch.add_documents(documents=shard)
    et = time.time() - st
    logger.info(f'Shard completed in {et} seconds.')
    return 0

if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--opensearch-cluster-domain", type=str, default=None)
    parser.add_argument("--opensearch-secretid", type=str, default=None)
    parser.add_argument("--opensearch-index-name", type=str, default=None)
    parser.add_argument("--aws-region", type=str, default="us-east-1")
    parser.add_argument("--embeddings-model-endpoint-name", type=str, default=None)
    parser.add_argument("--chunk-size-for-doc-split", type=int, default=500)
    parser.add_argument("--chunk-overlap-for-doc-split", type=int, default=30)
    parser.add_argument("--input-data-dir", type=str, default="/opt/ml/processing/input_data")
    parser.add_argument("--process-count", type=int, default=1)
    parser.add_argument("--create-index-hint-file", type=str, default="_create_index_hint")
    args, _ = parser.parse_known_args()

    logger.info("Received arguments {}".format(args))
    # list all the files
    files = glob.glob(os.path.join(args.input_data_dir, "*.*"))
    logger.info(f"there are {len(files)} files to process in the {args.input_data_dir} folder")
    
    # retrieve secret to talk to opensearch
    creds = get_credentials(args.opensearch_secretid, args.aws_region)
    http_auth = (creds['username'], creds['password'])
    
    
    loader = ReadTheDocsLoader(args.input_data_dir)
    text_splitter = RecursiveCharacterTextSplitter(
        # Set a really small chunk size, just to show.
        chunk_size=args.chunk_size_for_doc_split,
        chunk_overlap=args.chunk_overlap_for_doc_split,
        length_function=len,
    )
    
    # Stage one: read all the docs, split them into chunks. 
    st = time.time() 
    logger.info('Loading documents ...')
    docs = loader.load()
    
    # add a custom metadata field, such as timestamp
    for doc in docs:
        doc.metadata['timestamp'] = time.time()
        doc.metadata['embeddings_model'] = args.embeddings_model_endpoint_name
    chunks = text_splitter.create_documents([doc.page_content for doc in docs], metadatas=[doc.metadata for doc in docs])
    et = time.time() - st
    logger.info(f'Time taken: {et} seconds. {len(chunks)} chunks generated') 
    
    
    db_shards = (len(chunks) // MAX_OS_DOCS_PER_PUT) + 1
    print(f'Loading chunks into vector store ... using {db_shards} shards') 
    st = time.time()
    shards = np.array_split(chunks, db_shards)
    
    t1 = time.time()
    
    # first check if index exists, if it does then call the add_documents function
    # otherwise call the from_documents function which would first create the index
    # and then do a bulk add. Both add_documents and from_documents do a bulk add
    # but it is important to call from_documents first so that the index is created
    # correctly for K-NN
    index_exists = check_if_index_exists(args.opensearch_index_name,
                                         args.aws_region,
                                         args.opensearch_cluster_domain,
                                         http_auth)
    
    embeddings = create_sagemaker_embeddings_from_js_model(args.embeddings_model_endpoint_name, args.aws_region)
    
    if index_exists is False:
        # create an index if the create index hint file exists
        path = os.path.join(args.input_data_dir, args.create_index_hint_file)
        if os.path.isfile(path) is True:
            logger.info(f"index {args.opensearch_index_name} does not exist but {path} file is present so will create index")
            # by default langchain would create a k-NN index and the embeddings would be ingested as a k-NN vector type
            docsearch = OpenSearchVectorSearch.from_documents(index_name=args.opensearch_index_name,
                                                              documents=shards[0],
                                                              embedding=embeddings,
                                                              opensearch_url=args.opensearch_cluster_domain,
                                                              http_auth=http_auth)
            # we now need to start the loop below for the second shard
            shard_start_index = 1  
        else:
            logger.info(f"index {args.opensearch_index_name} does not exist and {path} file is not present, "
                        f"will wait for some other node to create the index")
            shard_start_index = 0
            # start a loop to wait for index creation by another node
            time_slept = 0
            while True:
                logger.info(f"index {args.opensearch_index_name} still does not exist, sleeping...")
                time.sleep(PER_ITER_SLEEP_TIME)
                index_exists = check_if_index_exists(args.opensearch_index_name,
                                                     args.aws_region,
                                                     args.opensearch_cluster_domain,
                                                     http_auth)
                if index_exists is True:
                    logger.info(f"index {args.opensearch_index_name} now exists")
                    break
                time_slept += PER_ITER_SLEEP_TIME
                if time_slept >= TOTAL_INDEX_CREATION_WAIT_TIME:
                    logger.error(f"time_slept={time_slept} >= {TOTAL_INDEX_CREATION_WAIT_TIME}, not waiting anymore for index creation")
                    break
                
    else:
        logger.info(f"index={args.opensearch_index_name} does exists, going to call add_documents")
        shard_start_index = 0
        
    with mp.Pool(processes = args.process_count) as pool:
        results = pool.map(partial(process_shard,
                                   embeddings_model_endpoint_name=args.embeddings_model_endpoint_name,
                                   aws_region=args.aws_region,
                                   os_index_name=args.opensearch_index_name,
                                   os_domain_ep=args.opensearch_cluster_domain,
                                   os_http_auth=http_auth),
                           shards[shard_start_index:])
    
    t2 = time.time()
    logger.info(f'run time in seconds: {t2-t1:.2f}')
    logger.info("all done")
# Out:
# Overwriting container/load_data_into_opensearch.py

# %% [markdown]
# ---
#
# ## Load the data in a [FAISS](https://github.com/facebookresearch/faiss) index (Local mode)
#
# We now create a FAISS index to store the embeddings. This is an alternative to OpenSearch for storing embeddings in-memory. We write the FAISS index locally and then upoad the files to an S3 bucket. A Lambda function can then download these files from S3 and load the FAISS index in memory to perform a similarity search.

# %%
from langchain.vectorstores import FAISS
from container.sm_helper import create_sagemaker_embeddings_from_js_model
embeddings = create_sagemaker_embeddings_from_js_model(embeddings_model_endpoint_name, aws_region)

loader = ReadTheDocsLoader(DATA_DIR)
text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=CHUNK_SIZE_FOR_DOC_SPLIT,
    chunk_overlap=CHUNK_OVERLAP_FOR_DOC_SPLIT,
    length_function=len,
)
    
# read all the docs, split them into chunks. 
st = time.time() 
logger.info('Loading documents ...')
docs = loader.load()

# add a custom metadata field, such as timestamp
for doc in docs:
    doc.metadata['timestamp'] = time.time()
    doc.metadata['embeddings_model'] = embeddings_model_endpoint_name
chunks = text_splitter.create_documents([doc.page_content for doc in docs], metadatas=[doc.metadata for doc in docs])
et = time.time() - st
logger.info(f'Time taken: {et} seconds. {len(chunks)} chunks generated')
# Out:
# 2024-01-11 07:44:12,515,credentials,MainProcess,INFO,Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/langchain/document_loaders/readthedocs.py:30: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 30 of the file /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   _ = BeautifulSoup(
# 2024-01-11 07:44:12,617,834176171,MainProcess,INFO,Loading documents ...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/langchain/document_loaders/readthedocs.py:46: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 46 of the file /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(data, **self.bs_kwargs)
# 2024-01-11 07:44:31,967,834176171,MainProcess,INFO,Time taken: 19.349927186965942 seconds. 5322 chunks generated

# %% [markdown]
# Load the chunks into FAISS, we provide the embeddings object so that langchain can first convert the text chunks into embeddings and then store those embeddings into a FAISS index.

# %%
vector_db = FAISS.from_documents(chunks, embeddings)
# Out:
# 2024-01-11 07:57:46,622,sm_helper,MainProcess,INFO,got results for 5322 in 788.0825908184052s, length of embeddings list is 5322
# 2024-01-11 07:57:46,625,loader,MainProcess,INFO,Loading faiss with AVX2 support.
# 2024-01-11 07:57:46,743,loader,MainProcess,INFO,Successfully loaded faiss with AVX2 support.

# %% [markdown]
# Save to a local directory and upload to S3.

# %%
vector_db_path = FAISS_INDEX_DIR
vector_db.save_local(vector_db_path)

# %%
# upload this data to S3, to be used when we run the Sagemaker Processing Job
# !aws s3 cp --recursive $vector_db_path/ s3://$bucket/$app_name/$vector_db_path
# Out:
# upload: faiss_index/index.pkl to s3://sagemaker-us-east-1-626103420214/llm-apps/faiss_index/index.pkl
# upload: faiss_index/index.faiss to s3://sagemaker-us-east-1-626103420214/llm-apps/faiss_index/index.faiss

# %% [markdown]
# ---
#
# ## Load the data in a `OpenSearch` index via SageMaker Processing Job (Distributed mode)
#
# We now have a working script that is able to ingest data into an OpenSearch index. But for this to work for massive amounts of data we need to scale up the processing by running this code in a distributed fashion. We will do this using Sagemkaer Processing Job. This involves the following steps:
#
# 1. Create a custom container in which we will install the `langchain` and `opensearch-py` packges and then upload this container image to Amazon Elastic Container Registry (ECR).
# 2. Use the Sagemaker `ScriptProcessor` class to create a Sagemaker Processing job that will run on multiple nodes.
#     - The data files available in S3 are automatically distributed across in the Sagemaker Processing Job instances by setting `s3_data_distribution_type='ShardedByS3Key'` as part of the `ProcessingInput` provided to the processing job.
#     - Each node processes a subset of the files and this brings down the overall time required to ingest the data into Opensearch.
#     - Each node also uses Python `multiprocessing` to internally also parallelize the file processing. Thus, **there are two levels of parallelization happening, one at the cluster level where individual nodes are distributing the work (files) amongst themselves and another at the node level where the files in a node are also split between multiple processes running on the node**.

# %% [markdown]
# ### Create custom container
#
# We will now create a container locally and push the container image to ECR. **The container creation process takes about 1 minute**.
#
# 1. The container include all the Python packages we need i.e. `langchain`, `opensearch-py`, `sagemaker` and `beautifulsoup4`.
# 1. The container also includes the `credentials.py` script for retrieving credentials from Secrets Manager and `sm_helper.py` for helping to create SageMaker endpoint classes that langchain uses.

# %%
# %%writefile container/Dockerfile
#
# FROM python:3.9-slim-buster
#
# RUN apt-get -y update && apt-get install -y --no-install-recommends \
#          wget \
#          python3-pip \
#          python3-setuptools \
#          nginx \
#          ca-certificates \
#     && rm -rf /var/lib/apt/lists/*
#
# RUN ln -s /usr/bin/python3 /usr/bin/python
# RUN ln -s /usr/bin/pip3 /usr/bin/pip
#
# # pip leaves the install caches populated which uses a
# # significant amount of space. These optimizations save a fair
# # amount of space in the image, which reduces start up time.
# RUN pip --no-cache-dir install  langchain==0.0.149 opensearch-py==2.2.0 sagemaker==2.148.0 beautifulsoup4==4.12.2
#
# # Include python script for retrieving credentials
# # from AWS SecretsManager and Sagemaker helper classes
# ADD credentials.py /code/
# ADD sm_helper.py /code/
#
# # Set some environment variables. PYTHONUNBUFFERED keeps Python from buffering our standard
# # output stream, which means that logs can be delivered to the user quickly. PYTHONDONTWRITEBYTECODE
# # keeps Python from writing the .pyc files which are unnecessary in this case. We also update
# # PATH so that the train and serve programs are found when the container is invoked.
# ENV PYTHONUNBUFFERED=TRUE
# ENV PYTHONDONTWRITEBYTECODE=TRUE
# Out:
# Writing container/Dockerfile

# %%
# %%writefile scripts/build_and_push.sh
#
# #!/usr/bin/env bash
# # This script shows how to build the Docker image and push it to ECR to be ready for use
# # by SageMaker.
# # The argument to this script are the path to the Dockerfile, the image name and tag and the aws-region
# # in which the container is to be created. This will be used as the image on the local
# # machine and combined with the account and region to form the repository name for ECR.
#
# # override the built-in echo so that we can have a nice timestamped trace
# echo () {
#     builtin echo "$(date +'[%m-%d %H:%M:%S]'):" "$@"
# }
#
# if [ "$#" -eq 4 ]; then
#     dlc_account_id=$(aws sts get-caller-identity | jq .Account)
#     path_to_dockerfile=$1
#     image=$2
#     tag=$3
#     region=$4
#
# else
#     echo "missing mandatory command line arguments, see usage..."
#     echo "usage: $0 </path/to/Dockerfile> $1 <image-repo> $2 <image-tag> $3 <aws-region>"
#     exit 1
# fi
#
# # Get the account number associated with the current IAM credentials
# account=$(aws sts get-caller-identity --query Account --output text)
#
# if [ $? -ne 0 ]
# then
#     exit 255
# fi
#
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image}:${tag}"
# echo the full image name would be ${fullname}
#
# # If the repository doesn't exist in ECR, create it.
# aws ecr describe-repositories --region ${region} --repository-names "${image}" > /dev/null 2>&1
# if [ $? -ne 0 ]; then
#     echo "creating ECR repository : ${fullname} "
#     aws ecr create-repository --region ${region} --repository-name "${image}" > /dev/null
# else
#     echo "${image} repo already exists in ECR"
# fi
#
# # move to path of dockerfile
# cd ${path_to_dockerfile}
#
# # get credentials to login to ECR and, build and tag the image
# # note the use of DOCKER_BUILDKIT=1, this is needed for some mount instructions in the Dockerfile
# echo "going to start a docker build, image=${image}, using Dockerfile=${path_to_dockerfile}"
# aws ecr get-login-password --region ${region} \
# | docker login --username AWS --password-stdin ${account}.dkr.ecr.${region}.amazonaws.com
# DOCKER_BUILDKIT=1 docker build . -t ${image}  --build-arg dlc_account_id=${dlc_account_id} --build-arg region=${region}
# docker tag ${image} ${fullname}
# echo ${image} created
#
# # push the image to ECR
# cmd="aws ecr get-login-password --region ${region} | docker login --username AWS --password-stdin ${account}.dkr.ecr.${region}.amazonaws.com"
# echo going to run \"${cmd}\" to login to ECR
# ${cmd}
#
# cmd="docker push ${fullname}"
# echo going to run \"${cmd}\" to push image to ecr
# ${cmd}
# if [ $? -eq 0 ]; then
#     echo "Amazon ECR URI: ${fullname}"
# else
#     echo "Error: Image ${fullname} build and push failed"
#     exit 1
# fi
#
# echo "all done"
# Out:
# Writing scripts/build_and_push.sh

# %%
# Run script to build docker custom containe image and push it to ECR 
# Set region and sagemaker URI variables 
session = boto3.session.Session()
client = boto3.client("sts")
account_id = client.get_caller_identity()["Account"]
logger.info(f"region={aws_region}, account_id={account_id}")
# !bash scripts/build_and_push.sh $(pwd)/container $IMAGE $IMAGE_TAG $aws_region
# Out:
# 2024-01-11 07:57:50,656,383160684,MainProcess,INFO,region=us-east-1, account_id=626103420214
# [01-11 07:57:52]: the full image name would be 626103420214.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom:latest
# [01-11 07:57:52]: creating ECR repository : 626103420214.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom:latest
# [01-11 07:57:53]: going to start a docker build, image=load-data-opensearch-custom, using Dockerfile=/home/ec2-user/SageMaker/llm-apps-notebooks/notebooks/rag/container
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# [+] Building 0.0s (0/1)
# [+] Building 0.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
# [+] Building 0.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.2s
# [+] Building 0.5s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.1s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
# [+] Building 0.6s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.2s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 16.96MB / 27.14MB  0.2s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.2s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
# [+] Building 0.7s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.3s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.3s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.3s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
# [+] Building 0.8s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.4s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.4s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
# [+] Building 1.0s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.6s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.6s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.6s
# [+] Building 1.1s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.7s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.7s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.7s
# [+] Building 1.3s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.9s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
# [+] Building 1.4s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  1.0s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.1s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.0s
# [+] Building 1.5s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  1.1s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.2s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
# [+] Building 1.6s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  1.3s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.3s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
# [+] Building 1.8s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  1.4s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.4s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
# [+] Building 1.9s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  1.5s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.5s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
# [+] Building 2.0s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  1.6s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.6s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
# [+] Building 2.1s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  1.7s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.7s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
# [+] Building 2.2s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  1.8s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
# [+] Building 2.4s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  2.0s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
# [+] Building 2.5s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  2.1s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.1s
# [+] Building 2.6s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  2.2s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.2s
# [+] Building 2.7s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  2.3s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.3s
# [+] Building 2.8s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  2.4s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.4s
# [+] Building 3.0s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  2.6s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
# [+] Building 3.1s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  2.7s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.0s
# [+] Building 3.2s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  2.9s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.1s
# [+] Building 3.4s (4/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  3.0s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
# [+] Building 3.5s (5/11)
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  3.1s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recomm  0.0s
# [+] Building 3.7s (5/11)
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  3.1s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recomm  0.2s
# [+] Building 3.8s (5/11)
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  3.1s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recomm  0.3s
# [+] Building 4.0s (5/11)
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  3.1s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recomm  0.5s
# [+] Building 4.1s (5/11)
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  3.1s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recomm  0.6s
#  => => # Get:1 http://deb.debian.org/debian buster InRelease [122 kB]
#  => => # Get:2 http://deb.debian.org/debian-security buster/updates InRelease [
#  => => # 34.8 kB]
#  => => # Get:3 http://deb.debian.org/debian buster-updates InRelease [56.6 kB]
#  => => # Get:4 http://deb.debian.org/debian buster/main amd64 Packages [7909 kB
#  => => # ]
# [+] Building 4.3s (5/11)
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  3.1s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
# ...
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recom  16.4s
#  => [3/7] RUN ln -s /usr/bin/python3 /usr/bin/python                       0.5s
#  => [4/7] RUN ln -s /usr/bin/pip3 /usr/bin/pip                             0.6s
#  => [5/7] RUN pip --no-cache-dir install  langchain==0.0.149 opensearch-  34.6s
#  => [6/7] ADD credentials.py /code/                                        0.0s
#  => [7/7] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     1.5s
#  => => exporting layers                                                    1.5s
# [+] Building 57.3s (11/12)
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recom  16.4s
#  => [3/7] RUN ln -s /usr/bin/python3 /usr/bin/python                       0.5s
#  => [4/7] RUN ln -s /usr/bin/pip3 /usr/bin/pip                             0.6s
#  => [5/7] RUN pip --no-cache-dir install  langchain==0.0.149 opensearch-  34.6s
#  => [6/7] ADD credentials.py /code/                                        0.0s
#  => [7/7] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     1.6s
#  => => exporting layers                                                    1.6s
# [+] Building 57.5s (11/12)
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recom  16.4s
#  => [3/7] RUN ln -s /usr/bin/python3 /usr/bin/python                       0.5s
#  => [4/7] RUN ln -s /usr/bin/pip3 /usr/bin/pip                             0.6s
#  => [5/7] RUN pip --no-cache-dir install  langchain==0.0.149 opensearch-  34.6s
#  => [6/7] ADD credentials.py /code/                                        0.0s
#  => [7/7] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     1.8s
#  => => exporting layers                                                    1.8s
# [+] Building 57.6s (11/12)
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recom  16.4s
#  => [3/7] RUN ln -s /usr/bin/python3 /usr/bin/python                       0.5s
#  => [4/7] RUN ln -s /usr/bin/pip3 /usr/bin/pip                             0.6s
#  => [5/7] RUN pip --no-cache-dir install  langchain==0.0.149 opensearch-  34.6s
#  => [6/7] ADD credentials.py /code/                                        0.0s
#  => [7/7] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     1.9s
#  => => exporting layers                                                    1.9s
# [+] Building 57.8s (11/12)
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recom  16.4s
#  => [3/7] RUN ln -s /usr/bin/python3 /usr/bin/python                       0.5s
#  => [4/7] RUN ln -s /usr/bin/pip3 /usr/bin/pip                             0.6s
#  => [5/7] RUN pip --no-cache-dir install  langchain==0.0.149 opensearch-  34.6s
#  => [6/7] ADD credentials.py /code/                                        0.0s
#  => [7/7] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     2.1s
#  => => exporting layers                                                    2.1s
# [+] Building 57.9s (11/12)
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recom  16.4s
#  => [3/7] RUN ln -s /usr/bin/python3 /usr/bin/python                       0.5s
#  => [4/7] RUN ln -s /usr/bin/pip3 /usr/bin/pip                             0.6s
#  => [5/7] RUN pip --no-cache-dir install  langchain==0.0.149 opensearch-  34.6s
#  => [6/7] ADD credentials.py /code/                                        0.0s
#  => [7/7] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     2.2s
#  => => exporting layers                                                    2.2s
# [+] Building 58.1s (11/12)
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recom  16.4s
#  => [3/7] RUN ln -s /usr/bin/python3 /usr/bin/python                       0.5s
#  => [4/7] RUN ln -s /usr/bin/pip3 /usr/bin/pip                             0.6s
#  => [5/7] RUN pip --no-cache-dir install  langchain==0.0.149 opensearch-  34.6s
#  => [6/7] ADD credentials.py /code/                                        0.0s
#  => [7/7] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     2.4s
#  => => exporting layers                                                    2.4s
# [+] Building 58.1s (12/12) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.26kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.3s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 3.23kB                                        0.0s
#  => [1/7] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  3.1s
#  => => resolve docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => => sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6c 27.14MB / 27.14MB  0.9s
#  => => sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671e 2.78MB / 2.78MB  0.2s
#  => => sha256:8d53da26040835f622504d7762fad14d226ac414e 11.04MB / 11.04MB  0.4s
#  => => sha256:320a7a4250aba4249f458872adecf92eea88dc6abd2d76d 988B / 988B  0.0s
#  => => sha256:d5cca64dca485c37ccf06721e36a93bf4331b0404bf 1.37kB / 1.37kB  0.0s
#  => => sha256:c84dbfe3b8deeb39e17d121220107f8354a9083b468 6.82kB / 6.82kB  0.0s
#  => => sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c2 243B / 243B  0.9s
#  => => extracting sha256:8b91b88d557765cd8c6802668755a3f6dc4337b6ce15a17e  0.8s
#  => => sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1 3.14MB / 3.14MB  1.1s
#  => => extracting sha256:824416e234237961c9c5d4f41dfe5b295a3c35a671ee5288  0.1s
#  => => extracting sha256:8d53da26040835f622504d7762fad14d226ac414efeb5363  0.5s
#  => => extracting sha256:84c8c79126f669beec1dcf6f34cd88094471745570c19c29  0.0s
#  => => extracting sha256:2e1c130fa3ec1777a82123374b4c500623959f903c1dd731  0.2s
#  => [2/7] RUN apt-get -y update && apt-get install -y --no-install-recom  16.4s
#  => [3/7] RUN ln -s /usr/bin/python3 /usr/bin/python                       0.5s
#  => [4/7] RUN ln -s /usr/bin/pip3 /usr/bin/pip                             0.6s
#  => [5/7] RUN pip --no-cache-dir install  langchain==0.0.149 opensearch-  34.6s
#  => [6/7] ADD credentials.py /code/                                        0.0s
#  => [7/7] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     2.4s
#  => => exporting layers                                                    2.4s
#  => => writing image sha256:39fda295ad27bffe9512b7abbba4472531fad00ba0860  0.0s
#  => => naming to docker.io/library/load-data-opensearch-custom             0.0s
# [01-11 07:58:52]: load-data-opensearch-custom created
# [01-11 07:58:52]: going to run "aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 626103420214.dkr.ecr.us-east-1.amazonaws.com" to login to ECR
#
# Unknown options: |,docker,login,--username,AWS,--password-stdin,626103420214.dkr.ecr.us-east-1.amazonaws.com
# [01-11 07:58:53]: going to run "docker push 626103420214.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom:latest" to push image to ecr
# The push refers to repository [626103420214.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom]
#
# 6da70cf9: Preparing
# 78d5bb3e: Preparing
# 0c2a8ca1: Preparing
# ec3c260c: Preparing
# 6045b772: Preparing
# 0440b11b: Preparing
# a27560c1: Preparing
# 037e08b3: Preparing
# eede8d6e: Preparing
# 55769c5e: Preparing
# 0c2a8ca1: Pushed     244MB/232.9MB[2KPushing  46.18MB/81.19MBlatest: digest: sha256:c55abed1447245d215585c96d5820ea086642a93930faae65d241b170a84b95c size: 2623
# [01-11 07:59:09]: Amazon ECR URI: 626103420214.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom:latest
# [01-11 07:59:09]: all done

# %% [markdown]
# ### Create and run the Sagemaker Processing Job
#
# Now we will run the Sagemaker Processing Job to ingest the data into OpenSearch.

# %%
# setup the parameters for the job
base_job_name = f"{app_name}-job"
tags = [{"Key": "data", "Value": "embeddings-for-llm-apps"}]

# use the custom container we just created
image_uri = f"{account_id}.dkr.ecr.{aws_region}.amazonaws.com/{IMAGE}:{IMAGE_TAG}"

# instance type and count determined via trial and error: how much overall processing time
# and what compute cost works best for your use-case
instance_type = "ml.m5.xlarge"
instance_count = 3
logger.info(f"base_job_name={base_job_name}, tags={tags}, image_uri={image_uri}, instance_type={instance_type}, instance_count={instance_count}")

# setup the ScriptProcessor with the above parameters
processor = ScriptProcessor(base_job_name=base_job_name,
                            image_uri=image_uri,
                            role=aws_role,
                            instance_type=instance_type,
                            instance_count=instance_count,
                            command=["python3"],
                            tags=tags)

# setup input from S3, note the ShardedByS3Key, this ensures that 
# each instance gets a random and equal subset of the files in S3.
inputs = [ProcessingInput(source=f"s3://{bucket}/{app_name}/{DOMAIN}",
                          destination='/opt/ml/processing/input_data',
                          s3_data_distribution_type='ShardedByS3Key',
                          s3_data_type='S3Prefix')]


logger.info(f"creating an opensearch index with name={opensearch_index}")
# ready to run the processing job
st = time.time()
processor.run(code="container/load_data_into_opensearch.py",
              inputs=inputs,
              outputs=[],
              arguments=["--opensearch-cluster-domain", opensearch_domain_endpoint,
                         "--opensearch-secretid", os_creds_secretid_in_secrets_manager,
                         "--opensearch-index-name", opensearch_index,
                         "--aws-region", aws_region,
                         "--embeddings-model-endpoint-name", embeddings_model_endpoint_name,
                         "--chunk-size-for-doc-split", str(CHUNK_SIZE_FOR_DOC_SPLIT),
                         "--chunk-overlap-for-doc-split", str(CHUNK_OVERLAP_FOR_DOC_SPLIT),
                         "--input-data-dir", "/opt/ml/processing/input_data",
                         "--create-index-hint-file", CREATE_OS_INDEX_HINT_FILE,
                         "--process-count", "2"])
time_taken = time.time() - st
logger.info(f"processing job completed, total time taken={time_taken}s")
preprocessing_job_description = processor.jobs[-1].describe()
logger.info(preprocessing_job_description)
# Out:
# 2024-01-11 07:59:09,330,2568289917,MainProcess,INFO,base_job_name=llm-apps-job, tags=[{'Key': 'data', 'Value': 'embeddings-for-llm-apps'}], image_uri=626103420214.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom:latest, instance_type=ml.m5.xlarge, instance_count=3
# 2024-01-11 07:59:09,362,2568289917,MainProcess,INFO,creating an opensearch index with name=llm_apps_workshop_embeddings
# 2024-01-11 07:59:09,686,session,MainProcess,INFO,Creating processing-job with name llm-apps-job-2024-01-11-07-59-09-363
# ...........................2024-01-11 08:03:40,202,load_data_into_opensearch,MainProcess,INFO,Received arguments Namespace(opensearch_cluster_domain='https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com', opensearch_secretid='OpenSearchSecret-opensearch-vector-llm-rag', opensearch_index_name='llm_apps_workshop_embeddings', aws_region='us-east-1', embeddings_model_endpoint_name='llm-apps-gpt-j-6b-endpoint-34b5c520', chunk_size_for_doc_split=600, chunk_overlap_for_doc_split=20, input_data_dir='/opt/ml/processing/input_data', process_count=2, create_index_hint_file='_create_index_hint')
# 2024-01-11 08:03:40,203,load_data_into_opensearch,MainProcess,INFO,there are 59 files to process in the /opt/ml/processing/input_data folder
# /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py:30: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
# The code that caused this warning is on line 30 of the file /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#   _ = BeautifulSoup(
# 2024-01-11 08:03:40,395,load_data_into_opensearch,MainProcess,INFO,Loading documents ...
# /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py:46: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
# The code that caused this warning is on line 46 of the file /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#   soup = BeautifulSoup(data, **self.bs_kwargs)
# 2024-01-11 08:03:40,182,load_data_into_opensearch,MainProcess,INFO,Received arguments Namespace(opensearch_cluster_domain='https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com', opensearch_secretid='OpenSearchSecret-opensearch-vector-llm-rag', opensearch_index_name='llm_apps_workshop_embeddings', aws_region='us-east-1', embeddings_model_endpoint_name='llm-apps-gpt-j-6b-endpoint-34b5c520', chunk_size_for_doc_split=600, chunk_overlap_for_doc_split=20, input_data_dir='/opt/ml/processing/input_data', process_count=2, create_index_hint_file='_create_index_hint')
# 2024-01-11 08:03:40,183,load_data_into_opensearch,MainProcess,INFO,there are 58 files to process in the /opt/ml/processing/input_data folder
# /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py:30: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
# The code that caused this warning is on line 30 of the file /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#   _ = BeautifulSoup(
# 2024-01-11 08:03:40,384,load_data_into_opensearch,MainProcess,INFO,Loading documents ...
# /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py:46: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
# The code that caused this warning is on line 46 of the file /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#   soup = BeautifulSoup(data, **self.bs_kwargs)
# 2024-01-11 08:03:40,332,load_data_into_opensearch,MainProcess,INFO,Received arguments Namespace(opensearch_cluster_domain='https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com', opensearch_secretid='OpenSearchSecret-opensearch-vector-llm-rag', opensearch_index_name='llm_apps_workshop_embeddings', aws_region='us-east-1', embeddings_model_endpoint_name='llm-apps-gpt-j-6b-endpoint-34b5c520', chunk_size_for_doc_split=600, chunk_overlap_for_doc_split=20, input_data_dir='/opt/ml/processing/input_data', process_count=2, create_index_hint_file='_create_index_hint')
# 2024-01-11 08:03:40,333,load_data_into_opensearch,MainProcess,INFO,there are 59 files to process in the /opt/ml/processing/input_data folder
# /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py:30: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
# The code that caused this warning is on line 30 of the file /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#   _ = BeautifulSoup(
# 2024-01-11 08:03:40,546,load_data_into_opensearch,MainProcess,INFO,Loading documents ...
# /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py:46: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
# The code that caused this warning is on line 46 of the file /usr/local/lib/python3.9/site-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#   soup = BeautifulSoup(data, **self.bs_kwargs)
# 2024-01-11 08:03:46,396,load_data_into_opensearch,MainProcess,INFO,Time taken: 6.012054443359375 seconds. 1466 chunks generated
# Loading chunks into vector store ... using 3 shards
# 2024-01-11 08:03:48,460,load_data_into_opensearch,MainProcess,INFO,Time taken: 7.914721250534058 seconds. 2049 chunks generated
# Loading chunks into vector store ... using 5 shards
# 2024-01-11 08:03:48,488,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:03:48,546,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings does not exist and /opt/ml/processing/input_data/_create_index_hint file is not present, will wait for some other node to create the index
# 2024-01-11 08:03:48,546,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:03:46,805,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:03:46,859,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings does not exist but /opt/ml/processing/input_data/_create_index_hint file is present so will create index
# 2024-01-11 08:03:47,742,load_data_into_opensearch,MainProcess,INFO,Time taken: 7.347906589508057 seconds. 1807 chunks generated
# Loading chunks into vector store ... using 4 shards
# 2024-01-11 08:03:47,770,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:03:47,931,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings does not exist and /opt/ml/processing/input_data/_create_index_hint file is not present, will wait for some other node to create the index
# 2024-01-11 08:03:47,932,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:03:52,959,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:03:52,959,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:03:53,574,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:03:53,574,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:03:57,983,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:03:57,983,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:03:58,608,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:03:58,608,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:03,009,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:03,009,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:03,636,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:03,636,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:08,037,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:08,038,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:08,659,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:08,659,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:13,060,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:13,060,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:13,691,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:13,691,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:18,084,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:18,084,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:18,717,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:18,718,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:23,109,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:23,109,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:23,746,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:23,746,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:28,142,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:28,142,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:28,772,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:28,772,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:33,167,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:33,167,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:33,799,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:33,799,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:38,190,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:38,190,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:38,830,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:38,831,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:43,211,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:43,211,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:43,858,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:43,859,load_data_into_opensearch,MainProcess,INFO,index llm_apps_workshop_embeddings still does not exist, sleeping...
# 2024-01-11 08:04:48,235,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:48,235,load_data_into_opensearch,MainProcess,ERROR,time_slept=60 >= 60, not waiting anymore for index creation
# 2024-01-11 08:04:48,276,load_data_into_opensearch,ForkPoolWorker-1,INFO,Starting process_shard of 452 chunks.
# 2024-01-11 08:04:48,279,load_data_into_opensearch,ForkPoolWorker-2,INFO,Starting process_shard of 452 chunks.
# 2024-01-11 08:04:48,888,load_data_into_opensearch,MainProcess,INFO,index_name=llm_apps_workshop_embeddings, exists=False
# 2024-01-11 08:04:48,888,load_data_into_opensearch,MainProcess,ERROR,time_slept=60 >= 60, not waiting anymore for index creation
# 2024-01-11 08:04:48,945,load_data_into_opensearch,ForkPoolWorker-1,INFO,Starting process_shard of 410 chunks.
# 2024-01-11 08:04:48,945,load_data_into_opensearch,ForkPoolWorker-2,INFO,Starting process_shard of 410 chunks.
# 2024-01-11 08:05:22,065,sm_helper,MainProcess,INFO,got results for 489 in 95.20527267456055s, length of embeddings list is 489
# 2024-01-11 08:05:22,462,base,MainProcess,INFO,PUT https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings [status:200 request:0.397s]
# 2024-01-11 08:05:26,357,base,MainProcess,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:1.760s]
# 2024-01-11 08:05:26,451,base,MainProcess,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.064s]
# 2024-01-11 08:05:26,507,load_data_into_opensearch,ForkPoolWorker-1,INFO,Starting process_shard of 489 chunks.
# 2024-01-11 08:05:26,510,load_data_into_opensearch,ForkPoolWorker-2,INFO,Starting process_shard of 488 chunks.
# 2024-01-11 08:08:15,986,sm_helper,ForkPoolWorker-1,INFO,got results for 410 in 206.97703194618225s, length of embeddings list is 410
# 2024-01-11 08:08:16,299,sm_helper,ForkPoolWorker-2,INFO,got results for 410 in 207.28981113433838s, length of embeddings list is 410
# 2024-01-11 08:08:19,191,base,ForkPoolWorker-1,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:1.405s]
# 2024-01-11 08:08:19,540,base,ForkPoolWorker-1,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.337s]
# 2024-01-11 08:08:19,559,load_data_into_opensearch,ForkPoolWorker-1,INFO,Shard completed in 210.6143856048584 seconds.
# 2024-01-11 08:08:19,565,load_data_into_opensearch,ForkPoolWorker-1,INFO,Starting process_shard of 410 chunks.
# 2024-01-11 08:08:19,686,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:1.555s]
# 2024-01-11 08:08:19,737,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.039s]
# 2024-01-11 08:08:19,756,load_data_into_opensearch,ForkPoolWorker-2,INFO,Shard completed in 210.81051516532898 seconds.
# 2024-01-11 08:08:19,761,load_data_into_opensearch,ForkPoolWorker-2,INFO,Starting process_shard of 410 chunks.
# 2024-01-11 08:08:30,686,sm_helper,ForkPoolWorker-2,INFO,got results for 452 in 222.33740830421448s, length of embeddings list is 452
# 2024-01-11 08:08:33,758,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:1.090s]
# 2024-01-11 08:08:33,895,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.125s]
# 2024-01-11 08:08:33,916,load_data_into_opensearch,ForkPoolWorker-2,INFO,Shard completed in 225.63634037971497 seconds.
# 2024-01-11 08:08:33,920,load_data_into_opensearch,ForkPoolWorker-2,INFO,Starting process_shard of 452 chunks.
# 2024-01-11 08:08:34,952,sm_helper,ForkPoolWorker-1,INFO,got results for 452 in 226.60498070716858s, length of embeddings list is 452
# 2024-01-11 08:08:37,948,base,ForkPoolWorker-1,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:1.017s]
# 2024-01-11 08:08:38,084,base,ForkPoolWorker-1,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.124s]
# 2024-01-11 08:08:38,104,load_data_into_opensearch,ForkPoolWorker-1,INFO,Shard completed in 229.82808661460876 seconds.
# 2024-01-11 08:08:38,108,load_data_into_opensearch,ForkPoolWorker-1,INFO,Starting process_shard of 451 chunks.
# 2024-01-11 08:09:48,308,sm_helper,ForkPoolWorker-2,INFO,got results for 488 in 261.73337864875793s, length of embeddings list is 488
# 2024-01-11 08:09:50,930,sm_helper,ForkPoolWorker-1,INFO,got results for 489 in 264.35743594169617s, length of embeddings list is 489
# 2024-01-11 08:09:51,593,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:1.140s]
# 2024-01-11 08:09:51,743,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.139s]
# 2024-01-11 08:09:51,764,load_data_into_opensearch,ForkPoolWorker-2,INFO,Shard completed in 265.25461888313293 seconds.
# 2024-01-11 08:09:54,217,base,ForkPoolWorker-1,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:1.139s]
# 2024-01-11 08:09:54,373,base,ForkPoolWorker-1,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.145s]
# 2024-01-11 08:09:54,395,load_data_into_opensearch,ForkPoolWorker-1,INFO,Shard completed in 267.8877112865448 seconds.
# 2024-01-11 08:09:54,407,load_data_into_opensearch,MainProcess,INFO,run time in seconds: 368.01
# 2024-01-11 08:09:54,407,load_data_into_opensearch,MainProcess,INFO,all done
# 2024-01-11 08:11:12,247,sm_helper,ForkPoolWorker-2,INFO,got results for 410 in 172.432213306427s, length of embeddings list is 410
# 2024-01-11 08:11:15,004,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:0.961s]
# 2024-01-11 08:11:15,107,sm_helper,ForkPoolWorker-1,INFO,got results for 410 in 175.48659896850586s, length of embeddings list is 410
# 2024-01-11 08:11:15,133,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.118s]
# 2024-01-11 08:11:15,166,load_data_into_opensearch,ForkPoolWorker-2,INFO,Shard completed in 175.40450406074524 seconds.
# 2024-01-11 08:11:15,172,load_data_into_opensearch,ForkPoolWorker-2,INFO,Starting process_shard of 409 chunks.
# 2024-01-11 08:11:17,958,base,ForkPoolWorker-1,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:1.013s]
# 2024-01-11 08:11:18,086,base,ForkPoolWorker-1,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.117s]
# 2024-01-11 08:11:18,106,load_data_into_opensearch,ForkPoolWorker-1,INFO,Shard completed in 178.5403938293457 seconds.
# 2024-01-11 08:11:35,432,sm_helper,ForkPoolWorker-1,INFO,got results for 451 in 177.27261543273926s, length of embeddings list is 451
# 2024-01-11 08:11:37,242,sm_helper,ForkPoolWorker-2,INFO,got results for 452 in 183.270414352417s, length of embeddings list is 452
# 2024-01-11 08:11:38,445,base,ForkPoolWorker-1,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:1.040s]
# 2024-01-11 08:11:38,580,base,ForkPoolWorker-1,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.126s]
# 2024-01-11 08:11:38,600,load_data_into_opensearch,ForkPoolWorker-1,INFO,Shard completed in 180.492271900177 seconds.
# 2024-01-11 08:11:40,282,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:1.079s]
# 2024-01-11 08:11:40,434,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.143s]
# 2024-01-11 08:11:40,455,load_data_into_opensearch,ForkPoolWorker-2,INFO,Shard completed in 186.53436040878296 seconds.
# 2024-01-11 08:11:40,467,load_data_into_opensearch,MainProcess,INFO,run time in seconds: 472.72
# 2024-01-11 08:11:40,467,load_data_into_opensearch,MainProcess,INFO,all done
#
# 2024-01-11 08:12:24,718,sm_helper,ForkPoolWorker-2,INFO,got results for 409 in 69.27578330039978s, length of embeddings list is 409
# 2024-01-11 08:12:27,469,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/_bulk [status:200 request:0.971s]
# 2024-01-11 08:12:27,588,base,ForkPoolWorker-2,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_refresh [status:200 request:0.108s]
# 2024-01-11 08:12:27,606,load_data_into_opensearch,ForkPoolWorker-2,INFO,Shard completed in 72.43360590934753 seconds.
# 2024-01-11 08:12:27,618,load_data_into_opensearch,MainProcess,INFO,run time in seconds: 519.16
# 2024-01-11 08:12:27,618,load_data_into_opensearch,MainProcess,INFO,all done
# 2024-01-11 08:12:46,794,2568289917,MainProcess,INFO,processing job completed, total time taken=817.4311027526855s
# 2024-01-11 08:12:46,899,2568289917,MainProcess,INFO,{'ProcessingInputs': [{'InputName': 'input-1', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-626103420214/llm-apps/sagemaker.readthedocs.io', 'LocalPath': '/opt/ml/processing/input_data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'ShardedByS3Key', 'S3CompressionType': 'None'}}, {'InputName': 'code', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-626103420214/llm-apps-job-2024-01-11-07-59-09-363/input/code/load_data_into_opensearch.py', 'LocalPath': '/opt/ml/processing/input/code', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}], 'ProcessingJobName': 'llm-apps-job-2024-01-11-07-59-09-363', 'ProcessingResources': {'ClusterConfig': {'InstanceCount': 3, 'InstanceType': 'ml.m5.xlarge', 'VolumeSizeInGB': 30}}, 'StoppingCondition': {'MaxRuntimeInSeconds': 86400}, 'AppSpecification': {'ImageUri': '626103420214.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom:latest', 'ContainerEntrypoint': ['python3', '/opt/ml/processing/input/code/load_data_into_opensearch.py'], 'ContainerArguments': ['--opensearch-cluster-domain', 'https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com', '--opensearch-secretid', 'OpenSearchSecret-opensearch-vector-llm-rag', '--opensearch-index-name', 'llm_apps_workshop_embeddings', '--aws-region', 'us-east-1', '--embeddings-model-endpoint-name', 'llm-apps-gpt-j-6b-endpoint-34b5c520', '--chunk-size-for-doc-split', '600', '--chunk-overlap-for-doc-split', '20', '--input-data-dir', '/opt/ml/processing/input_data', '--create-index-hint-file', '_create_index_hint', '--process-count', '2']}, 'RoleArn': 'arn:aws:iam::626103420214:role/LLMAppsIAMRole', 'ProcessingJobArn': 'arn:aws:sagemaker:us-east-1:626103420214:processing-job/llm-apps-job-2024-01-11-07-59-09-363', 'ProcessingJobStatus': 'Completed', 'ProcessingEndTime': datetime.datetime(2024, 1, 11, 8, 12, 29, 406000, tzinfo=tzlocal()), 'ProcessingStartTime': datetime.datetime(2024, 1, 11, 8, 3, 31, 51000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2024, 1, 11, 8, 12, 29, 997000, tzinfo=tzlocal()), 'CreationTime': datetime.datetime(2024, 1, 11, 7, 59, 9, 798000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '90cd8bc4-e1a2-4e2f-922d-ab4879e5bf7f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '90cd8bc4-e1a2-4e2f-922d-ab4879e5bf7f', 'content-type': 'application/x-amz-json-1.1', 'content-length': '2003', 'date': 'Thu, 11 Jan 2024 08:12:46 GMT'}, 'RetryAttempts': 0}}

# %% [markdown]
# ## Step 3: Do a similarity search for for user input to documents (embeddings) in OpenSearch

# %%
from container.credentials import get_credentials
from langchain.vectorstores import OpenSearchVectorSearch
from container.sm_helper import create_sagemaker_embeddings_from_js_model

creds = get_credentials(os_creds_secretid_in_secrets_manager, aws_region)
http_auth = (creds['username'], creds['password'])
docsearch = OpenSearchVectorSearch(index_name=opensearch_index,
                                   embedding_function=create_sagemaker_embeddings_from_js_model(embeddings_model_endpoint_name,
                                                                                                aws_region),
                                   opensearch_url=opensearch_domain_endpoint,
                                   http_auth=http_auth)
q = "Which XGBoost versions does SageMaker support?"
docs = docsearch.similarity_search(q, k=3) #, search_type="script_scoring", space_type="cosinesimil"
for doc in docs:
    logger.info("----------")
    logger.info(f"content=\"{doc.page_content}\",\nmetadata=\"{doc.metadata}\"")
# Out:
# 2024-01-11 08:12:47,037,credentials,MainProcess,INFO,Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# 2024-01-11 08:12:47,622,base,MainProcess,INFO,POST https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com:443/llm_apps_workshop_embeddings/_search [status:200 request:0.144s]
# 2024-01-11 08:12:47,632,263489938,MainProcess,INFO,----------
# 2024-01-11 08:12:47,633,263489938,MainProcess,INFO,content="an expanded set of metrics than the original versions. It provides an XGBoost estimator that executes a training script in a managed XGBoost environment. The current release of SageMaker XGBoost is based on the original XGBoost versions 1.0, 1.2, 1.3, and 1.5.
# The following table outlines a variety of sample notebooks that address different use cases of Amazon SageMaker XGBoost algorithm.
# Notebook Title
# Description
# How to Create a Custom XGBoost container?
# This notebook shows you how to build a custom XGBoost Container with Amazon SageMaker Batch Transform.",
# metadata="{'source': '/opt/ml/processing/input_data/sagemaker.readthedocs.io_en_stable_algorithms_tabular_xgboost.html', 'timestamp': 1704960228.4131098, 'embeddings_model': 'llm-apps-gpt-j-6b-endpoint-34b5c520'}"
# 2024-01-11 08:12:47,638,263489938,MainProcess,INFO,----------
# 2024-01-11 08:12:47,639,263489938,MainProcess,INFO,content="If you don’t need the features and flexibility of open source XGBoost, consider using the built-in version.
# For information about using the Amazon SageMaker XGBoost built-in algorithm, see XGBoost Algorithm
# in the Amazon SageMaker Developer Guide.
# Use the Open Source XGBoost Algorithm¶
# If you want the flexibility and additional features that it provides, use the SageMaker open source XGBoost algorithm.
# For which XGBoost versions are supported, see the AWS documentation.
# We recommend that you use the latest supported version because that’s where we focus most of our development efforts.",
# metadata="{'source': '/opt/ml/processing/input_data/sagemaker.readthedocs.io_en_stable_frameworks_xgboost_using_xgboost.html', 'timestamp': 1704960227.6992655, 'embeddings_model': 'llm-apps-gpt-j-6b-endpoint-34b5c520'}"
# 2024-01-11 08:12:47,640,263489938,MainProcess,INFO,----------
# 2024-01-11 08:12:47,641,263489938,MainProcess,INFO,content="Latest version - The open source XGBoost algorithm typically supports a more recent version of XGBoost.
# To see the XGBoost version that is currently supported,
# see XGBoost SageMaker Estimators and Models.
# Flexibility - Take advantage of the full range of XGBoost functionality, such as cross-validation support.
# You can add custom pre- and post-processing logic and run additional code after training.
# Scalability - The XGBoost open source algorithm has a more efficient implementation of distributed training,
# which enables it to scale out to more instances and reduce out-of-memory errors.",
# metadata="{'source': '/opt/ml/processing/input_data/sagemaker.readthedocs.io_en_stable_frameworks_xgboost_using_xgboost.html', 'timestamp': 1704960227.6992655, 'embeddings_model': 'llm-apps-gpt-j-6b-endpoint-34b5c520'}"

# %%
opensearch_domain_endpoint
# Out:
# 'https://search-opensearchservi-yputae1aigke-xhac3qry45u6mtuoplaxmo7a7a.us-east-1.es.amazonaws.com'

# %% [markdown]
# ---
#
# ## Conclusion
# In this notebook we were able to see how to use LLMs deployed on a SageMaker Endpoint to generate embeddings and then ingest those embeddings into OpenSearch and finally do a similarity search for user input to the documents (embeddings) stored in OpenSearch. We used langchain as an abstraction layer to talk to both the SageMaker Endpoint as well as OpenSearch.
